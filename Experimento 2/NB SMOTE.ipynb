# %% [markdown]
# _Alberto Medrano Fernández_
#
# # NB (SMOTE)

# %% [markdown]
# ---
#
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from time import time

from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler, LabelEncoder 
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.neural_network import BernoulliRBM
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

from tensorflow.keras.models import load_model, Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Input, Dense, BatchNormalization, ReLU, LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping

from imblearn.over_sampling import SMOTE

# %% [markdown]
# ---
#
# ## Dataset

# %%
hikari_2022 = pd.read_csv('ALLFLOWMETER_HIKARI2022.csv', sep=',')
hikari_2022
# Out:
#         Unnamed: 0                 uid       originh  originp  \
# 0                0  Cmu9v81jToQyRF1gbk  184.0.48.168    38164
# 1                1  CO21hl3TWkuXTOgajk  184.0.48.169    43068
# 2                2  CBLJ6L19FP0MfYX7Oh  184.0.48.124     5678
# 3                3  ChTG451zJ7hUYOcqje  184.0.48.124     5678
# 4                4  Cn9y6E2KVxzQbs5wjc  184.0.48.124     5678
# ...            ...                 ...           ...      ...
# 228248       16634   Clt16PPxzrXEtpa5d   184.0.48.20    53866
# 228249       53170  Cs8RA72uHDiQa5ch2k   184.0.48.20    54318
# 228250       53529  Cy4dqo4YEq5YGxjUXa   184.0.48.20    65355
# 228251       86308  CFXfNV3OTG04e0UnP4   184.0.48.20    53642
# 228252       99240  CqO7kc2eC5InNvWrtl   184.0.48.20    61000
#
#                 responh  responp           flow_duration  fwd_pkts_tot  \
# 0          184.0.48.150    50443  0 days 00:00:00.000060             1
# 1          184.0.48.150    50443  0 days 00:00:00.000083             1
# 2       255.255.255.255     5678  0 days 00:01:59.996602             3
# 3       255.255.255.255     5678  0 days 00:00:59.996909             2
# 4       255.255.255.255     5678  0 days 00:00:59.992130             2
# ...                 ...      ...                     ...           ...
# 228248     184.0.48.255     1947  0 days 00:00:00.000027             2
# 228249     184.0.48.255     1947  0 days 00:00:00.000027             2
# 228250     184.0.48.255     1947         0 days 00:00:00             2
# 228251     184.0.48.255     1947  0 days 00:00:00.000054             2
# 228252     184.0.48.255     1947         0 days 00:00:00             2
#
#         bwd_pkts_tot  fwd_data_pkts_tot  ...      idle.max      idle.tot  \
# 0                  1                  0  ...  0.000000e+00  0.000000e+00
# 1                  1                  0  ...  0.000000e+00  0.000000e+00
# 2                  0                  3  ...  5.999912e+07  1.199966e+08
# 3                  0                  2  ...  5.999691e+07  5.999691e+07
# 4                  0                  2  ...  5.999213e+07  5.999213e+07
# ...              ...                ...  ...           ...           ...
# 228248             0                  2  ...  0.000000e+00  0.000000e+00
# 228249             0                  2  ...  0.000000e+00  0.000000e+00
# 228250             0                  2  ...  0.000000e+00  0.000000e+00
# 228251             0                  2  ...  0.000000e+00  0.000000e+00
# 228252             0                  2  ...  0.000000e+00  0.000000e+00
#
#             idle.avg     idle.std  fwd_init_window_size  bwd_init_window_size  \
# 0       0.000000e+00     0.000000                 64240                     0
# 1       0.000000e+00     0.000000                 64240                     0
# 2       5.999830e+07  1156.846698                     0                     0
# 3       5.999691e+07     0.000000                     0                     0
# 4       5.999213e+07     0.000000                     0                     0
# ...              ...          ...                   ...                   ...
# 228248  0.000000e+00     0.000000                     0                     0
# 228249  0.000000e+00     0.000000                     0                     0
# 228250  0.000000e+00     0.000000                     0                     0
# 228251  0.000000e+00     0.000000                     0                     0
# 228252  0.000000e+00     0.000000                     0                     0
#
#         fwd_last_window_size  bwd_last_window_size      attack_category  Label
# 0                      64240                     0               Benign      0
# 1                      64240                     0               Benign      0
# 2                          0                     0               Benign      0
# 3                          0                     0               Benign      0
# 4                          0                     0               Benign      0
# ...                      ...                   ...                  ...    ...
# 228248                     0                     0  XMRIGCC CryptoMiner      1
# 228249                     0                     0  XMRIGCC CryptoMiner      1
# 228250                     0                     0  XMRIGCC CryptoMiner      1
# 228251                     0                     0  XMRIGCC CryptoMiner      1
# 228252                     0                     0  XMRIGCC CryptoMiner      1
#
# [228253 rows x 88 columns]

# %%
hikari_2022 = hikari_2022.drop(columns=['Unnamed: 0', 'uid', 'originh', 'responh', 'flow_duration', 'fwd_URG_flag_count', 
                                        'bwd_URG_flag_count', 'attack_category'])
hikari_2022
# Out:
#         originp  responp  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  \
# 0         38164    50443             1             1                  0
# 1         43068    50443             1             1                  0
# 2          5678     5678             3             0                  3
# 3          5678     5678             2             0                  2
# 4          5678     5678             2             0                  2
# ...         ...      ...           ...           ...                ...
# 228248    53866     1947             2             0                  2
# 228249    54318     1947             2             0                  2
# 228250    65355     1947             2             0                  2
# 228251    53642     1947             2             0                  2
# 228252    61000     1947             2             0                  2
#
#         bwd_data_pkts_tot  fwd_pkts_per_sec  bwd_pkts_per_sec  \
# 0                       0      16644.063492      16644.063492
# 1                       0      12052.597701      12052.597701
# 2                       0          0.025001          0.000000
# 3                       0          0.033335          0.000000
# 4                       0          0.033338          0.000000
# ...                   ...               ...               ...
# 228248                  0      73584.280702          0.000000
# 228249                  0      74235.469027          0.000000
# 228250                  0          0.000000          0.000000
# 228251                  0      37117.734513          0.000000
# 228252                  0          0.000000          0.000000
#
#         flow_pkts_per_sec  down_up_ratio  ...      idle.min      idle.max  \
# 0            33288.126984            1.0  ...  0.000000e+00  0.000000e+00
# 1            24105.195402            1.0  ...  0.000000e+00  0.000000e+00
# 2                0.025001            0.0  ...  5.999748e+07  5.999912e+07
# 3                0.033335            0.0  ...  5.999691e+07  5.999691e+07
# 4                0.033338            0.0  ...  5.999213e+07  5.999213e+07
# ...                   ...            ...  ...           ...           ...
# 228248       73584.280702            0.0  ...  0.000000e+00  0.000000e+00
# 228249       74235.469027            0.0  ...  0.000000e+00  0.000000e+00
# 228250           0.000000            0.0  ...  0.000000e+00  0.000000e+00
# 228251       37117.734513            0.0  ...  0.000000e+00  0.000000e+00
# 228252           0.000000            0.0  ...  0.000000e+00  0.000000e+00
#
#             idle.tot      idle.avg     idle.std  fwd_init_window_size  \
# 0       0.000000e+00  0.000000e+00     0.000000                 64240
# 1       0.000000e+00  0.000000e+00     0.000000                 64240
# 2       1.199966e+08  5.999830e+07  1156.846698                     0
# 3       5.999691e+07  5.999691e+07     0.000000                     0
# 4       5.999213e+07  5.999213e+07     0.000000                     0
# ...              ...           ...          ...                   ...
# 228248  0.000000e+00  0.000000e+00     0.000000                     0
# 228249  0.000000e+00  0.000000e+00     0.000000                     0
# 228250  0.000000e+00  0.000000e+00     0.000000                     0
# 228251  0.000000e+00  0.000000e+00     0.000000                     0
# 228252  0.000000e+00  0.000000e+00     0.000000                     0
#
#         bwd_init_window_size  fwd_last_window_size  bwd_last_window_size  \
# 0                          0                 64240                     0
# 1                          0                 64240                     0
# 2                          0                     0                     0
# 3                          0                     0                     0
# 4                          0                     0                     0
# ...                      ...                   ...                   ...
# 228248                     0                     0                     0
# 228249                     0                     0                     0
# 228250                     0                     0                     0
# 228251                     0                     0                     0
# 228252                     0                     0                     0
#
#         Label
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 228248      1
# 228249      1
# 228250      1
# 228251      1
# 228252      1
#
# [228253 rows x 80 columns]

# %%
# Calculate Pearson correlation coefficient
corr = hikari_2022.corr(method ='pearson')

# Extract the correlation with the target variable 'Label'
corr_with_target = corr['Label']

# Select only columns with a correlation less than 0.05
relevant_features = corr_with_target[abs(corr_with_target) >= 0.05].index

# Filter the DataFrame to keep only the relevant features
hikari_2022 = hikari_2022[relevant_features]

print("Dataset after EDA:")
hikari_2022
# Out:
# Dataset after EDA:
#         originp  responp  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  \
# 0         38164    50443             1             1                  0
# 1         43068    50443             1             1                  0
# 2          5678     5678             3             0                  3
# 3          5678     5678             2             0                  2
# 4          5678     5678             2             0                  2
# ...         ...      ...           ...           ...                ...
# 228248    53866     1947             2             0                  2
# 228249    54318     1947             2             0                  2
# 228250    65355     1947             2             0                  2
# 228251    53642     1947             2             0                  2
# 228252    61000     1947             2             0                  2
#
#         bwd_data_pkts_tot  bwd_pkts_per_sec  down_up_ratio  \
# 0                       0      16644.063492            1.0
# 1                       0      12052.597701            1.0
# 2                       0          0.000000            0.0
# 3                       0          0.000000            0.0
# 4                       0          0.000000            0.0
# ...                   ...               ...            ...
# 228248                  0          0.000000            0.0
# 228249                  0          0.000000            0.0
# 228250                  0          0.000000            0.0
# 228251                  0          0.000000            0.0
# 228252                  0          0.000000            0.0
#
#         fwd_header_size_tot  fwd_header_size_min  ...  bwd_subflow_bytes  \
# 0                        40                   40  ...                0.0
# 1                        40                   40  ...                0.0
# 2                        24                    8  ...                0.0
# 3                        16                    8  ...                0.0
# 4                        16                    8  ...                0.0
# ...                     ...                  ...  ...                ...
# 228248                   16                    8  ...                0.0
# 228249                   16                    8  ...                0.0
# 228250                   16                    8  ...                0.0
# 228251                   16                    8  ...                0.0
# 228252                   16                    8  ...                0.0
#
#         fwd_bulk_packets  bwd_bulk_packets  active.min  active.max  \
# 0                    0.0               0.0   60.081482   60.081482
# 1                    0.0               0.0   82.969666   82.969666
# 2                    0.0               0.0    0.000000    0.000000
# 3                    0.0               0.0    0.000000    0.000000
# 4                    0.0               0.0    0.000000    0.000000
# ...                  ...               ...         ...         ...
# 228248               0.0               0.0   27.179718   27.179718
# 228249               0.0               0.0   26.941299   26.941299
# 228250               0.0               0.0    0.000000    0.000000
# 228251               0.0               0.0   53.882599   53.882599
# 228252               0.0               0.0    0.000000    0.000000
#
#         active.avg  fwd_init_window_size  bwd_init_window_size  \
# 0        60.081482                 64240                     0
# 1        82.969666                 64240                     0
# 2         0.000000                     0                     0
# 3         0.000000                     0                     0
# 4         0.000000                     0                     0
# ...            ...                   ...                   ...
# 228248   27.179718                     0                     0
# 228249   26.941299                     0                     0
# 228250    0.000000                     0                     0
# 228251   53.882599                     0                     0
# 228252    0.000000                     0                     0
#
#         fwd_last_window_size  Label
# 0                      64240      0
# 1                      64240      0
# 2                          0      0
# 3                          0      0
# 4                          0      0
# ...                      ...    ...
# 228248                     0      1
# 228249                     0      1
# 228250                     0      1
# 228251                     0      1
# 228252                     0      1
#
# [228253 rows x 44 columns]

# %% [markdown]
# ---
#
# ## Models

# %% [markdown]
# ### Without feature extraction

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Cross-validation
def cross_validation(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []

    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Resample with SMOTE 
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
        print("X_train_resampled, ", X_train_resampled.shape)
        print("y_train_resampled, ", y_train_resampled.value_counts())
        
        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train_resampled)
        X_test = scaler.transform(X_test)

        # Train Naive Bayes classifier
        nb_classifier = GaussianNB()
        nb_classifier.fit(X_train, y_train_resampled)

        # Make predictions
        y_pred = nb_classifier.predict(X_test)

        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")   



tiempo_inicial = time()
#
cross_validation(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# X_train_resampled,  (343860, 43)
# y_train_resampled,  Label
# 0    171930
# 1    171930
# Name: count, dtype: int64
# Fold accuracy: 0.9182712317364351
# Fold precision: 0.41765625
# Fold recall: 0.9985057900635039
# Fold F1-score: 0.5889611104990635
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     42974
#            1       0.42      1.00      0.59      2677
#
#     accuracy                           0.92     45651
#    macro avg       0.71      0.96      0.77     45651
# weighted avg       0.97      0.92      0.93     45651
#
# X_train_resampled,  (343952, 43)
# y_train_resampled,  Label
# 0    171976
# 1    171976
# Name: count, dtype: int64
# Fold accuracy: 0.9237037523822041
# Fold precision: 0.4386701097482247
# Fold recall: 0.9981637899375688
# Fold F1-score: 0.6094853683148335
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96     42928
#            1       0.44      1.00      0.61      2723
#
#     accuracy                           0.92     45651
#    macro avg       0.72      0.96      0.78     45651
# weighted avg       0.97      0.92      0.94     45651
#
# X_train_resampled,  (343710, 43)
# y_train_resampled,  Label
# 0    171855
# 1    171855
# Name: count, dtype: int64
# Fold accuracy: 0.9277343322161618
# Fold precision: 0.44086203970812826
# Fold recall: 0.9984627209838586
# Fold F1-score: 0.6116539140670983
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96     43049
#            1       0.44      1.00      0.61      2602
#
#     accuracy                           0.93     45651
#    macro avg       0.72      0.96      0.79     45651
# weighted avg       0.97      0.93      0.94     45651
#
# X_train_resampled,  (343910, 43)
# y_train_resampled,  Label
# 0    171955
# 1    171955
# Name: count, dtype: int64
# Fold accuracy: 0.9226067907995619
# Fold precision: 0.43324775353016687
# Fold recall: 0.9996297667530544
# Fold F1-score: 0.6045001679167133
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96     42949
#            1       0.43      1.00      0.60      2701
#
#     accuracy                           0.92     45650
#    macro avg       0.72      0.96      0.78     45650
# weighted avg       0.97      0.92      0.94     45650
#
# X_train_resampled,  (343800, 43)
# y_train_resampled,  Label
# 0    171900
# 1    171900
# Name: count, dtype: int64
# Fold accuracy: 0.9256078860898138
# Fold precision: 0.4379139072847682
# Fold recall: 0.9996220710506425
# Fold F1-score: 0.6090260188809579
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96     43004
#            1       0.44      1.00      0.61      2646
#
#     accuracy                           0.93     45650
#    macro avg       0.72      0.96      0.78     45650
# weighted avg       0.97      0.93      0.94     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9235847986448352
# Mean precision: 0.43367001205425754
# Mean recall: 0.9988768277577256
# Mean F1-score: 0.6047253159357333
#
# El tiempo de ejecucion fue: 4.415289878845215

# %% [markdown]
# ---
#
# ### With DNN

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the DNN model
def create_dnn(input_dim):
    inputs = Input(shape=(input_dim,))
    
    # Hidden layer 1
    x = Dense(input_dim * 2)(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    # Hidden layer 2
    x = Dense(input_dim)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    # Feature layer
    n_bottleneck = round(float(input_dim) / 2.0)
    bottleneck = Dense(n_bottleneck)(x)
    bottleneck = BatchNormalization()(bottleneck)
    bottleneck = ReLU()(bottleneck)
    
    # Output layer
    outputs = Dense(1, activation='sigmoid')(bottleneck)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    # Model for feature extraction
    feature_extractor = Model(inputs=inputs, outputs=bottleneck)
    
    return model, feature_extractor

# Cross-validation
def cross_validation_dnn(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Resample with SMOTE 
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
        print("X_train_resampled, ", X_train_resampled.shape)
        print("y_train_resampled, ", y_train_resampled.value_counts())
        
        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train_resampled)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        dnn, feature_extractor = create_dnn(n_inputs)
        
        # Early Stopping
        early_stopping1 = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)
        early_stopping2 = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
        
        # Fit the DNN model
        dnn.fit(X_train, y_train_resampled, epochs=100, batch_size=32, verbose=1,
                        validation_data=(X_test, y_test),
                        callbacks=[early_stopping1, early_stopping2])
        
        # Encode the data
        X_train_encoded = feature_extractor.predict(X_train)
        X_test_encoded = feature_extractor.predict(X_test)
        
        # Train Naive Bayes classifier
        nb_classifier_encoded = GaussianNB()
        nb_classifier_encoded.fit(X_train_encoded, y_train_resampled)
        
        # Make predictions
        y_pred_encoded = nb_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")


tiempo_inicial = time()
#
cross_validation_dnn(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# X_train_resampled,  (343860, 43)
# y_train_resampled,  Label
# 0    171930
# 1    171930
# Name: count, dtype: int64
# Epoch 1/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 10s 783us/step - accuracy: 0.9838 - loss: 0.0611 - val_accuracy: 0.9783 - val_loss: 0.0963
# Epoch 2/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 8s 767us/step - accuracy: 0.9899 - loss: 0.0372 - val_accuracy: 0.9824 - val_loss: 0.0397
# Epoch 3/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 8s 771us/step - accuracy: 0.9902 - loss: 0.0357 - val_accuracy: 0.9815 - val_loss: 0.0563
# Epoch 4/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 8s 770us/step - accuracy: 0.9904 - loss: 0.0351 - val_accuracy: 0.9818 - val_loss: 0.0535
# Epoch 5/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 8s 770us/step - accuracy: 0.9902 - loss: 0.0356 - val_accuracy: 0.9821 - val_loss: 0.0476
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 5s 443us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 440us/step
# Fold accuracy: 0.9826509824538345
# Fold precision: 0.7721628645682934
# Fold recall: 0.9988793425476279
# Fold F1-score: 0.8710097719869707
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     42974
#            1       0.77      1.00      0.87      2677
#
#     accuracy                           0.98     45651
#    macro avg       0.89      0.99      0.93     45651
# weighted avg       0.99      0.98      0.98     45651
#
# X_train_resampled,  (343952, 43)
# y_train_resampled,  Label
# 0    171976
# 1    171976
# Name: count, dtype: int64
# Epoch 1/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 10s 792us/step - accuracy: 0.9844 - loss: 0.0605 - val_accuracy: 0.9803 - val_loss: 0.0527
# Epoch 2/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 780us/step - accuracy: 0.9898 - loss: 0.0370 - val_accuracy: 0.9801 - val_loss: 0.0556
# Epoch 3/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 780us/step - accuracy: 0.9900 - loss: 0.0364 - val_accuracy: 0.9815 - val_loss: 0.0518
# Epoch 4/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 783us/step - accuracy: 0.9901 - loss: 0.0358 - val_accuracy: 0.9806 - val_loss: 0.0539
# Epoch 5/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 779us/step - accuracy: 0.9903 - loss: 0.0355 - val_accuracy: 0.9801 - val_loss: 0.0640
# Epoch 6/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 780us/step - accuracy: 0.9903 - loss: 0.0358 - val_accuracy: 0.9819 - val_loss: 0.0503
# Epoch 7/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 782us/step - accuracy: 0.9901 - loss: 0.0356 - val_accuracy: 0.9821 - val_loss: 0.0502
# Epoch 8/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 780us/step - accuracy: 0.9901 - loss: 0.0356 - val_accuracy: 0.9816 - val_loss: 0.0518
# Epoch 9/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 781us/step - accuracy: 0.9900 - loss: 0.0360 - val_accuracy: 0.9821 - val_loss: 0.0554
# Epoch 10/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 784us/step - accuracy: 0.9906 - loss: 0.0343 - val_accuracy: 0.9820 - val_loss: 0.0493
# Epoch 11/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 779us/step - accuracy: 0.9906 - loss: 0.0346 - val_accuracy: 0.9818 - val_loss: 0.0511
# Epoch 12/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 786us/step - accuracy: 0.9905 - loss: 0.0347 - val_accuracy: 0.9817 - val_loss: 0.0511
# Epoch 13/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 781us/step - accuracy: 0.9904 - loss: 0.0349 - val_accuracy: 0.9822 - val_loss: 0.0505
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 5s 444us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 437us/step
# Fold accuracy: 0.9824757398523581
# Fold precision: 0.7743223965763195
# Fold recall: 0.9966948218876239
# Fold F1-score: 0.8715478484264612
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     42928
#            1       0.77      1.00      0.87      2723
#
#     accuracy                           0.98     45651
#    macro avg       0.89      0.99      0.93     45651
# weighted avg       0.99      0.98      0.98     45651
#
# X_train_resampled,  (343710, 43)
# y_train_resampled,  Label
# 0    171855
# 1    171855
# Name: count, dtype: int64
# Epoch 1/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 10s 781us/step - accuracy: 0.9847 - loss: 0.0575 - val_accuracy: 0.9819 - val_loss: 0.0475
# Epoch 2/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 8s 775us/step - accuracy: 0.9894 - loss: 0.0378 - val_accuracy: 0.9819 - val_loss: 0.0510
# Epoch 3/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 8s 775us/step - accuracy: 0.9897 - loss: 0.0374 - val_accuracy: 0.9820 - val_loss: 0.0550
# Epoch 4/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 8s 771us/step - accuracy: 0.9900 - loss: 0.0360 - val_accuracy: 0.9825 - val_loss: 0.0507
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 5s 438us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 435us/step
# Fold accuracy: 0.9829576570064182
# Fold precision: 0.7706231454005935
# Fold recall: 0.9980784012298232
# Fold F1-score: 0.8697253851306095
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     43049
#            1       0.77      1.00      0.87      2602
#
#     accuracy                           0.98     45651
#    macro avg       0.89      0.99      0.93     45651
# weighted avg       0.99      0.98      0.98     45651
#
# X_train_resampled,  (343910, 43)
# y_train_resampled,  Label
# 0    171955
# 1    171955
# Name: count, dtype: int64
# Epoch 1/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 10s 793us/step - accuracy: 0.9834 - loss: 0.0625 - val_accuracy: 0.9804 - val_loss: 0.0543
# Epoch 2/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 783us/step - accuracy: 0.9897 - loss: 0.0374 - val_accuracy: 0.9813 - val_loss: 0.0536
# Epoch 3/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 787us/step - accuracy: 0.9897 - loss: 0.0373 - val_accuracy: 0.9814 - val_loss: 0.0515
# Epoch 4/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 782us/step - accuracy: 0.9905 - loss: 0.0350 - val_accuracy: 0.9803 - val_loss: 0.0543
# Epoch 5/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 779us/step - accuracy: 0.9904 - loss: 0.0354 - val_accuracy: 0.9813 - val_loss: 0.0524
# Epoch 6/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 783us/step - accuracy: 0.9904 - loss: 0.0352 - val_accuracy: 0.9812 - val_loss: 0.0509
# Epoch 7/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 780us/step - accuracy: 0.9900 - loss: 0.0362 - val_accuracy: 0.9813 - val_loss: 0.0523
# Epoch 8/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 783us/step - accuracy: 0.9904 - loss: 0.0353 - val_accuracy: 0.9800 - val_loss: 0.0536
# Epoch 9/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 780us/step - accuracy: 0.9903 - loss: 0.0355 - val_accuracy: 0.9813 - val_loss: 0.0510
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 5s 442us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 433us/step
# Fold accuracy: 0.9818400876232202
# Fold precision: 0.7654566080544526
# Fold recall: 0.9992595335061089
# Fold F1-score: 0.8668700819013971
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     42949
#            1       0.77      1.00      0.87      2701
#
#     accuracy                           0.98     45650
#    macro avg       0.88      0.99      0.93     45650
# weighted avg       0.99      0.98      0.98     45650
#
# X_train_resampled,  (343800, 43)
# y_train_resampled,  Label
# 0    171900
# 1    171900
# Name: count, dtype: int64
# Epoch 1/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 10s 780us/step - accuracy: 0.9795 - loss: 0.0701 - val_accuracy: 0.9807 - val_loss: 0.0564
# Epoch 2/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 8s 770us/step - accuracy: 0.9899 - loss: 0.0370 - val_accuracy: 0.9810 - val_loss: 0.0497
# Epoch 3/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 8s 776us/step - accuracy: 0.9902 - loss: 0.0357 - val_accuracy: 0.9818 - val_loss: 0.0504
# Epoch 4/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 8s 770us/step - accuracy: 0.9900 - loss: 0.0363 - val_accuracy: 0.9821 - val_loss: 0.0489
# Epoch 5/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 8s 777us/step - accuracy: 0.9903 - loss: 0.0355 - val_accuracy: 0.9820 - val_loss: 0.0520
# Epoch 6/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 8s 770us/step - accuracy: 0.9902 - loss: 0.0358 - val_accuracy: 0.9812 - val_loss: 0.0519
# Epoch 7/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 8s 775us/step - accuracy: 0.9904 - loss: 0.0351 - val_accuracy: 0.9816 - val_loss: 0.0516
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 5s 440us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 443us/step
# Fold accuracy: 0.9826725082146769
# Fold precision: 0.7700145560407569
# Fold recall: 0.9996220710506425
# Fold F1-score: 0.8699227100805789
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     43004
#            1       0.77      1.00      0.87      2646
#
#     accuracy                           0.98     45650
#    macro avg       0.88      0.99      0.93     45650
# weighted avg       0.99      0.98      0.98     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9825193950301017
# Mean precision: 0.7705159141280832
# Mean recall: 0.9985068340443652
# Mean F1-score: 0.8698151595052035
#
# El tiempo de ejecucion fue: 373.6777582168579

# %% [markdown]
# ---
#
# ### With DBN

# %%
def visualize_dbn(layers, file_name='dbn_structure.png'):
    # Crear un grafo dirigido
    G = nx.DiGraph()

    # Añadir nodos para cada capa RBM
    for i, n_units in enumerate(layers):
        G.add_node(f"RBM {i+1}\n{n_units} unidades", layer=i+1)

    # Añadir aristas entre nodos (de una capa a otra)
    for i in range(len(layers) - 1):
        G.add_edge(f"RBM {i+1}\n{layers[i]} unidades", f"RBM {i+2}\n{layers[i+1]} unidades")

    # Dibujar el grafo
    pos = nx.spring_layout(G)  # Posición de los nodos
    nx.draw(G, pos, with_labels=True, node_size=3000, node_color='lightblue', font_size=10, font_weight='bold')
    
    # Guardar la imagen a un archivo
    plt.title("Arquitectura de la DBN")
    plt.savefig(file_name)
    plt.show()
    
#visualize_dbn([X.shape[1]*2, X.shape[1]])

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the DBN class
class DBN(BaseEstimator, TransformerMixin):
    def __init__(self, rbm_layers, rbm_learning_rate, rbm_n_iter):
        self.rbm_layers = rbm_layers
        self.rbm_learning_rate = rbm_learning_rate
        self.rbm_n_iter = rbm_n_iter
        self.rbms = []
        for i, n_components in enumerate(rbm_layers):
            self.rbms.append(BernoulliRBM(n_components=n_components, learning_rate=rbm_learning_rate, n_iter=rbm_n_iter, verbose=1))

    def fit(self, X, y=None):
        input_data = X
        for rbm in self.rbms:
            rbm.fit(input_data)
            input_data = rbm.transform(input_data)
        return self

    def transform(self, X):
        input_data = X
        for rbm in self.rbms:
            input_data = rbm.transform(input_data)
        return input_data

# Cross-validation
def cross_validation_dbn(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Resample with SMOTE 
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
        print("X_train_resampled, ", X_train_resampled.shape)
        print("y_train_resampled, ", y_train_resampled.value_counts())
        
        # Normalize data
        scaler = MinMaxScaler()
        X_train = scaler.fit_transform(X_train_resampled)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        dbn = DBN(rbm_layers=[n_inputs*2, n_inputs], rbm_learning_rate=0.1, rbm_n_iter=10)
        
        # Fit the DBN model
        dbn.fit(X_train)
        
        # Encode the data
        X_train_encoded = dbn.transform(X_train)
        X_test_encoded = dbn.transform(X_test)
        
        # Train Naive Bayes classifier
        nb_classifier_encoded = GaussianNB()
        nb_classifier_encoded.fit(X_train_encoded, y_train_resampled)
        
        # Make predictions
        y_pred_encoded = nb_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")
    
    
tiempo_inicial = time()
#
cross_validation_dbn(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# X_train_resampled,  (343860, 43)
# y_train_resampled,  Label
# 0    171930
# 1    171930
# Name: count, dtype: int64
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.36, time = 4.64s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.35, time = 5.73s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.26, time = 5.75s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.21, time = 5.86s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -5.15, time = 5.65s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -5.23, time = 5.66s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -5.04, time = 5.77s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.89, time = 5.65s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -5.09, time = 5.62s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -5.22, time = 5.73s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -0.85, time = 4.51s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -2.05, time = 5.51s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -1.39, time = 5.36s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -0.70, time = 5.37s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -0.99, time = 5.47s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -0.74, time = 5.39s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -0.65, time = 5.32s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -0.70, time = 5.44s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -0.83, time = 5.30s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -0.71, time = 5.33s
# Fold accuracy: 0.911721539506254
# Fold precision: 0.3491638795986622
# Fold recall: 0.5849831901382144
# Fold F1-score: 0.4373080145210835
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     42974
#            1       0.35      0.58      0.44      2677
#
#     accuracy                           0.91     45651
#    macro avg       0.66      0.76      0.69     45651
# weighted avg       0.94      0.91      0.92     45651
#
# X_train_resampled,  (343952, 43)
# y_train_resampled,  Label
# 0    171976
# 1    171976
# Name: count, dtype: int64
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.59, time = 4.67s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.38, time = 5.88s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.19, time = 5.90s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.29, time = 5.94s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -5.27, time = 5.76s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -5.39, time = 5.81s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -5.20, time = 5.72s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -5.20, time = 5.77s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -5.26, time = 5.94s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -5.20, time = 5.85s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -0.85, time = 4.44s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -0.75, time = 5.39s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -0.70, time = 5.31s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -0.66, time = 5.32s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -0.87, time = 5.38s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -0.66, time = 5.32s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -0.59, time = 5.31s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -0.62, time = 5.36s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -0.65, time = 5.31s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -0.61, time = 5.36s
# Fold accuracy: 0.9163435631201945
# Fold precision: 0.3714821763602251
# Fold recall: 0.5817113477781858
# Fold F1-score: 0.45341348218119365
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95     42928
#            1       0.37      0.58      0.45      2723
#
#     accuracy                           0.92     45651
#    macro avg       0.67      0.76      0.70     45651
# weighted avg       0.94      0.92      0.92     45651
#
# X_train_resampled,  (343710, 43)
# y_train_resampled,  Label
# 0    171855
# 1    171855
# Name: count, dtype: int64
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.49, time = 4.69s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.33, time = 5.86s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.30, time = 5.91s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.09, time = 5.81s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -5.21, time = 5.84s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -5.05, time = 5.89s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -5.22, time = 5.81s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -5.05, time = 5.75s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -5.08, time = 5.95s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -5.17, time = 5.82s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.05, time = 4.51s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.63, time = 5.44s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.00, time = 5.33s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -3.95, time = 5.28s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -3.81, time = 5.38s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.08, time = 5.42s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.07, time = 5.30s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -3.77, time = 5.35s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -3.80, time = 5.28s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -3.98, time = 5.24s
# Fold accuracy: 0.9247990186414318
# Fold precision: 0.38785425101214577
# Fold recall: 0.5522674865488086
# Fold F1-score: 0.4556841604566355
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96     43049
#            1       0.39      0.55      0.46      2602
#
#     accuracy                           0.92     45651
#    macro avg       0.68      0.75      0.71     45651
# weighted avg       0.94      0.92      0.93     45651
#
# X_train_resampled,  (343910, 43)
# y_train_resampled,  Label
# 0    171955
# 1    171955
# Name: count, dtype: int64
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.34, time = 4.57s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.42, time = 6.00s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.16, time = 6.00s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.97, time = 5.83s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.92, time = 5.78s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -5.10, time = 5.93s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.98, time = 5.87s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.97, time = 5.78s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -5.07, time = 5.82s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.99, time = 5.81s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.63, time = 4.56s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.76, time = 5.38s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.15, time = 5.27s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.15, time = 5.35s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.57, time = 5.36s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.81, time = 5.27s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.61, time = 5.39s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -5.10, time = 5.28s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -6.40, time = 5.29s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.96, time = 5.35s
# Fold accuracy: 0.907645125958379
# Fold precision: 0.3333333333333333
# Fold recall: 0.5609033691225472
# Fold F1-score: 0.41816174441070936
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     42949
#            1       0.33      0.56      0.42      2701
#
#     accuracy                           0.91     45650
#    macro avg       0.65      0.75      0.68     45650
# weighted avg       0.93      0.91      0.92     45650
#
# X_train_resampled,  (343800, 43)
# y_train_resampled,  Label
# 0    171900
# 1    171900
# Name: count, dtype: int64
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.29, time = 4.61s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.31, time = 5.87s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.41, time = 5.99s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.16, time = 5.85s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -5.39, time = 5.79s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -5.24, time = 5.92s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -5.09, time = 5.76s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -5.14, time = 5.86s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -5.16, time = 5.80s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -5.11, time = 5.78s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -0.45, time = 4.53s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.58, time = 5.35s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -0.57, time = 5.29s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -0.50, time = 5.39s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -0.46, time = 5.32s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -0.45, time = 5.31s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -0.50, time = 5.40s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -0.70, time = 5.22s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -2.59, time = 5.28s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -0.48, time = 5.45s
# Fold accuracy: 0.9102738225629792
# Fold precision: 0.33663812528165843
# Fold recall: 0.564625850340136
# Fold F1-score: 0.42179559570863917
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     43004
#            1       0.34      0.56      0.42      2646
#
#     accuracy                           0.91     45650
#    macro avg       0.65      0.75      0.69     45650
# weighted avg       0.94      0.91      0.92     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9141566139578476
# Mean precision: 0.35569435311720493
# Mean recall: 0.5688982487855785
# Mean F1-score: 0.4372725994556522
#
# El tiempo de ejecucion fue: 567.815402507782

# %% [markdown]
# ---
#
# ### With Autoencoder

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the autoencoder model
def create_autoencoder(n_inputs):
    inputs = Input(shape=(n_inputs,))
    
    # Define Encoder
    e = Dense(n_inputs*2)(inputs)
    e = BatchNormalization()(e)
    e = LeakyReLU()(e)
    
    # Bottleneck
    n_bottleneck = round(float(n_inputs)/2.0)
    bottleneck = Dense(n_bottleneck)(e)
    
    # Define Decoder
    d = Dense(n_inputs*2)(bottleneck)
    d = BatchNormalization()(d)
    d = LeakyReLU()(d)
    
    # Output layer
    outputs = Dense(n_inputs, activation='linear')(d)
    
    # Define autoencoder model
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='mse')
    
    # Define encoder model
    encoder = Model(inputs=inputs, outputs=bottleneck)
    
    return model, encoder

# Cross-validation
def cross_validation_autoencoder(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Resample with SMOTE 
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
        print("X_train_resampled, ", X_train_resampled.shape)
        print("y_train_resampled, ", y_train_resampled.value_counts())
        
        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train_resampled)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        autoencoder, encoder = create_autoencoder(n_inputs)
        
        # Early Stopping
        early_stopping1 = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)
        early_stopping2 = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
        
        # Fit the DNN model
        autoencoder.fit(X_train, X_train, epochs=100, batch_size=32, verbose=1,
                        validation_data=(X_test, X_test),
                        callbacks=[early_stopping1, early_stopping2])
        
        # Encode the data
        X_train_encoded = encoder.predict(X_train)
        X_test_encoded = encoder.predict(X_test)
        
        # Train Naive Bayes classifier
        nb_classifier_encoded = GaussianNB()
        nb_classifier_encoded.fit(X_train_encoded, y_train_resampled)
        
        # Make predictions
        y_pred_encoded = nb_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")


tiempo_inicial = time()
#
cross_validation_autoencoder(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# X_train_resampled,  (343860, 43)
# y_train_resampled,  Label
# 0    171930
# 1    171930
# Name: count, dtype: int64
# Epoch 1/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 8s 681us/step - loss: 0.1671 - val_loss: 0.1057
# Epoch 2/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 677us/step - loss: 0.1010 - val_loss: 0.0404
# Epoch 3/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 675us/step - loss: 0.0630 - val_loss: 0.1359
# Epoch 4/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 678us/step - loss: 0.0734 - val_loss: 0.0320
# Epoch 5/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 677us/step - loss: 0.0759 - val_loss: 0.1626
# Epoch 6/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 8s 712us/step - loss: 0.0624 - val_loss: 0.0471
# Epoch 7/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 8s 708us/step - loss: 0.0353 - val_loss: 0.0470
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 5s 443us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 428us/step
# Fold accuracy: 0.9515235153665856
# Fold precision: 0.5475215075788611
# Fold recall: 0.9985057900635039
# Fold F1-score: 0.7072364069321339
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97     42974
#            1       0.55      1.00      0.71      2677
#
#     accuracy                           0.95     45651
#    macro avg       0.77      0.97      0.84     45651
# weighted avg       0.97      0.95      0.96     45651
#
# X_train_resampled,  (343952, 43)
# y_train_resampled,  Label
# 0    171976
# 1    171976
# Name: count, dtype: int64
# Epoch 1/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 9s 719us/step - loss: 0.2343 - val_loss: 0.0727
# Epoch 2/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 681us/step - loss: 0.1365 - val_loss: 0.1468
# Epoch 3/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 667us/step - loss: 0.0809 - val_loss: 0.0597
# Epoch 4/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 671us/step - loss: 0.0470 - val_loss: 0.0919
# Epoch 5/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 671us/step - loss: 0.0651 - val_loss: 0.0654
# Epoch 6/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 668us/step - loss: 0.0578 - val_loss: 0.1004
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 4s 403us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 401us/step
# Fold accuracy: 0.9429804385446102
# Fold precision: 0.5113507377979569
# Fold recall: 0.9926551597502754
# Fold F1-score: 0.6749906355350231
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97     42928
#            1       0.51      0.99      0.67      2723
#
#     accuracy                           0.94     45651
#    macro avg       0.76      0.97      0.82     45651
# weighted avg       0.97      0.94      0.95     45651
#
# X_train_resampled,  (343710, 43)
# y_train_resampled,  Label
# 0    171855
# 1    171855
# Name: count, dtype: int64
# Epoch 1/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 8s 676us/step - loss: 0.1500 - val_loss: 0.5096
# Epoch 2/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 7s 662us/step - loss: 0.0635 - val_loss: 0.6676
# Epoch 3/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 7s 663us/step - loss: 0.0643 - val_loss: 0.3615
# Epoch 4/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 7s 666us/step - loss: 0.0605 - val_loss: 0.2361
# Epoch 5/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 7s 663us/step - loss: 0.0459 - val_loss: 0.3328
# Epoch 6/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 7s 666us/step - loss: 0.0409 - val_loss: 0.2518
# Epoch 7/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 7s 663us/step - loss: 0.0344 - val_loss: 0.2965
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 4s 406us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 401us/step
# Fold accuracy: 0.9460471840704475
# Fold precision: 0.5138308457711442
# Fold recall: 0.9923136049192929
# Fold F1-score: 0.6770683099514881
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97     43049
#            1       0.51      0.99      0.68      2602
#
#     accuracy                           0.95     45651
#    macro avg       0.76      0.97      0.82     45651
# weighted avg       0.97      0.95      0.95     45651
#
# X_train_resampled,  (343910, 43)
# y_train_resampled,  Label
# 0    171955
# 1    171955
# Name: count, dtype: int64
# Epoch 1/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 683us/step - loss: 0.1450 - val_loss: 0.0619
# Epoch 2/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 711us/step - loss: 0.0751 - val_loss: 0.0495
# Epoch 3/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 7s 690us/step - loss: 0.0741 - val_loss: 0.0836
# Epoch 4/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 706us/step - loss: 0.0732 - val_loss: 0.4707
# Epoch 5/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 696us/step - loss: 0.0825 - val_loss: 0.0765
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 4s 413us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 406us/step
# Fold accuracy: 0.9451259583789704
# Fold precision: 0.5188824662813102
# Fold recall: 0.9970381340244354
# Fold F1-score: 0.6825497402103662
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97     42949
#            1       0.52      1.00      0.68      2701
#
#     accuracy                           0.95     45650
#    macro avg       0.76      0.97      0.83     45650
# weighted avg       0.97      0.95      0.95     45650
#
# X_train_resampled,  (343800, 43)
# y_train_resampled,  Label
# 0    171900
# 1    171900
# Name: count, dtype: int64
# Epoch 1/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 9s 709us/step - loss: 0.1690 - val_loss: 0.8036
# Epoch 2/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 8s 737us/step - loss: 0.0878 - val_loss: 0.0615
# Epoch 3/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 8s 700us/step - loss: 0.0794 - val_loss: 0.1607
# Epoch 4/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 7s 694us/step - loss: 0.0546 - val_loss: 0.1010
# Epoch 5/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 7s 690us/step - loss: 0.0534 - val_loss: 0.0337
# Epoch 6/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 7s 691us/step - loss: 0.0581 - val_loss: 0.0635
# Epoch 7/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 7s 687us/step - loss: 0.0364 - val_loss: 0.0844
# Epoch 8/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 7s 691us/step - loss: 0.0378 - val_loss: 0.0433
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 4s 406us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 400us/step
# Fold accuracy: 0.9462212486308872
# Fold precision: 0.5188325774009072
# Fold recall: 0.9943310657596371
# Fold F1-score: 0.6818711934689646
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97     43004
#            1       0.52      0.99      0.68      2646
#
#     accuracy                           0.95     45650
#    macro avg       0.76      0.97      0.83     45650
# weighted avg       0.97      0.95      0.95     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9463796689983003
# Mean precision: 0.5220836269660359
# Mean recall: 0.994968750903429
# Mean F1-score: 0.6847432572195952
#
# El tiempo de ejecucion fue: 292.5471317768097
