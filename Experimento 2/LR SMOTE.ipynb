# %% [markdown]
# _Alberto Medrano Fernández_
#
# # Logistic Regression (SMOTE)

# %% [markdown]
# ---
#
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from time import time

from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler, LabelEncoder 
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.neural_network import BernoulliRBM
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

from tensorflow.keras.models import load_model, Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Input, Dense, BatchNormalization, ReLU, LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping

from imblearn.over_sampling import SMOTE

# %% [markdown]
# ---
#
# ## Dataset

# %%
hikari_2022 = pd.read_csv('ALLFLOWMETER_HIKARI2022.csv', sep=',')
hikari_2022
# Out:
#         Unnamed: 0                 uid       originh  originp  \
# 0                0  Cmu9v81jToQyRF1gbk  184.0.48.168    38164
# 1                1  CO21hl3TWkuXTOgajk  184.0.48.169    43068
# 2                2  CBLJ6L19FP0MfYX7Oh  184.0.48.124     5678
# 3                3  ChTG451zJ7hUYOcqje  184.0.48.124     5678
# 4                4  Cn9y6E2KVxzQbs5wjc  184.0.48.124     5678
# ...            ...                 ...           ...      ...
# 228248       16634   Clt16PPxzrXEtpa5d   184.0.48.20    53866
# 228249       53170  Cs8RA72uHDiQa5ch2k   184.0.48.20    54318
# 228250       53529  Cy4dqo4YEq5YGxjUXa   184.0.48.20    65355
# 228251       86308  CFXfNV3OTG04e0UnP4   184.0.48.20    53642
# 228252       99240  CqO7kc2eC5InNvWrtl   184.0.48.20    61000
#
#                 responh  responp           flow_duration  fwd_pkts_tot  \
# 0          184.0.48.150    50443  0 days 00:00:00.000060             1
# 1          184.0.48.150    50443  0 days 00:00:00.000083             1
# 2       255.255.255.255     5678  0 days 00:01:59.996602             3
# 3       255.255.255.255     5678  0 days 00:00:59.996909             2
# 4       255.255.255.255     5678  0 days 00:00:59.992130             2
# ...                 ...      ...                     ...           ...
# 228248     184.0.48.255     1947  0 days 00:00:00.000027             2
# 228249     184.0.48.255     1947  0 days 00:00:00.000027             2
# 228250     184.0.48.255     1947         0 days 00:00:00             2
# 228251     184.0.48.255     1947  0 days 00:00:00.000054             2
# 228252     184.0.48.255     1947         0 days 00:00:00             2
#
#         bwd_pkts_tot  fwd_data_pkts_tot  ...      idle.max      idle.tot  \
# 0                  1                  0  ...  0.000000e+00  0.000000e+00
# 1                  1                  0  ...  0.000000e+00  0.000000e+00
# 2                  0                  3  ...  5.999912e+07  1.199966e+08
# 3                  0                  2  ...  5.999691e+07  5.999691e+07
# 4                  0                  2  ...  5.999213e+07  5.999213e+07
# ...              ...                ...  ...           ...           ...
# 228248             0                  2  ...  0.000000e+00  0.000000e+00
# 228249             0                  2  ...  0.000000e+00  0.000000e+00
# 228250             0                  2  ...  0.000000e+00  0.000000e+00
# 228251             0                  2  ...  0.000000e+00  0.000000e+00
# 228252             0                  2  ...  0.000000e+00  0.000000e+00
#
#             idle.avg     idle.std  fwd_init_window_size  bwd_init_window_size  \
# 0       0.000000e+00     0.000000                 64240                     0
# 1       0.000000e+00     0.000000                 64240                     0
# 2       5.999830e+07  1156.846698                     0                     0
# 3       5.999691e+07     0.000000                     0                     0
# 4       5.999213e+07     0.000000                     0                     0
# ...              ...          ...                   ...                   ...
# 228248  0.000000e+00     0.000000                     0                     0
# 228249  0.000000e+00     0.000000                     0                     0
# 228250  0.000000e+00     0.000000                     0                     0
# 228251  0.000000e+00     0.000000                     0                     0
# 228252  0.000000e+00     0.000000                     0                     0
#
#         fwd_last_window_size  bwd_last_window_size      attack_category  Label
# 0                      64240                     0               Benign      0
# 1                      64240                     0               Benign      0
# 2                          0                     0               Benign      0
# 3                          0                     0               Benign      0
# 4                          0                     0               Benign      0
# ...                      ...                   ...                  ...    ...
# 228248                     0                     0  XMRIGCC CryptoMiner      1
# 228249                     0                     0  XMRIGCC CryptoMiner      1
# 228250                     0                     0  XMRIGCC CryptoMiner      1
# 228251                     0                     0  XMRIGCC CryptoMiner      1
# 228252                     0                     0  XMRIGCC CryptoMiner      1
#
# [228253 rows x 88 columns]

# %%
hikari_2022 = hikari_2022.drop(columns=['Unnamed: 0', 'uid', 'originh', 'responh', 'flow_duration', 'fwd_URG_flag_count', 
                                        'bwd_URG_flag_count', 'attack_category'])
hikari_2022
# Out:
#         originp  responp  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  \
# 0         38164    50443             1             1                  0
# 1         43068    50443             1             1                  0
# 2          5678     5678             3             0                  3
# 3          5678     5678             2             0                  2
# 4          5678     5678             2             0                  2
# ...         ...      ...           ...           ...                ...
# 228248    53866     1947             2             0                  2
# 228249    54318     1947             2             0                  2
# 228250    65355     1947             2             0                  2
# 228251    53642     1947             2             0                  2
# 228252    61000     1947             2             0                  2
#
#         bwd_data_pkts_tot  fwd_pkts_per_sec  bwd_pkts_per_sec  \
# 0                       0      16644.063492      16644.063492
# 1                       0      12052.597701      12052.597701
# 2                       0          0.025001          0.000000
# 3                       0          0.033335          0.000000
# 4                       0          0.033338          0.000000
# ...                   ...               ...               ...
# 228248                  0      73584.280702          0.000000
# 228249                  0      74235.469027          0.000000
# 228250                  0          0.000000          0.000000
# 228251                  0      37117.734513          0.000000
# 228252                  0          0.000000          0.000000
#
#         flow_pkts_per_sec  down_up_ratio  ...      idle.min      idle.max  \
# 0            33288.126984            1.0  ...  0.000000e+00  0.000000e+00
# 1            24105.195402            1.0  ...  0.000000e+00  0.000000e+00
# 2                0.025001            0.0  ...  5.999748e+07  5.999912e+07
# 3                0.033335            0.0  ...  5.999691e+07  5.999691e+07
# 4                0.033338            0.0  ...  5.999213e+07  5.999213e+07
# ...                   ...            ...  ...           ...           ...
# 228248       73584.280702            0.0  ...  0.000000e+00  0.000000e+00
# 228249       74235.469027            0.0  ...  0.000000e+00  0.000000e+00
# 228250           0.000000            0.0  ...  0.000000e+00  0.000000e+00
# 228251       37117.734513            0.0  ...  0.000000e+00  0.000000e+00
# 228252           0.000000            0.0  ...  0.000000e+00  0.000000e+00
#
#             idle.tot      idle.avg     idle.std  fwd_init_window_size  \
# 0       0.000000e+00  0.000000e+00     0.000000                 64240
# 1       0.000000e+00  0.000000e+00     0.000000                 64240
# 2       1.199966e+08  5.999830e+07  1156.846698                     0
# 3       5.999691e+07  5.999691e+07     0.000000                     0
# 4       5.999213e+07  5.999213e+07     0.000000                     0
# ...              ...           ...          ...                   ...
# 228248  0.000000e+00  0.000000e+00     0.000000                     0
# 228249  0.000000e+00  0.000000e+00     0.000000                     0
# 228250  0.000000e+00  0.000000e+00     0.000000                     0
# 228251  0.000000e+00  0.000000e+00     0.000000                     0
# 228252  0.000000e+00  0.000000e+00     0.000000                     0
#
#         bwd_init_window_size  fwd_last_window_size  bwd_last_window_size  \
# 0                          0                 64240                     0
# 1                          0                 64240                     0
# 2                          0                     0                     0
# 3                          0                     0                     0
# 4                          0                     0                     0
# ...                      ...                   ...                   ...
# 228248                     0                     0                     0
# 228249                     0                     0                     0
# 228250                     0                     0                     0
# 228251                     0                     0                     0
# 228252                     0                     0                     0
#
#         Label
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 228248      1
# 228249      1
# 228250      1
# 228251      1
# 228252      1
#
# [228253 rows x 80 columns]

# %%
# Calculate Pearson correlation coefficient
corr = hikari_2022.corr(method ='pearson')

# Extract the correlation with the target variable 'Label'
corr_with_target = corr['Label']

# Select only columns with a correlation less than 0.05
relevant_features = corr_with_target[abs(corr_with_target) >= 0.05].index

# Filter the DataFrame to keep only the relevant features
hikari_2022 = hikari_2022[relevant_features]

print("Dataset after EDA:")
hikari_2022
# Out:
# Dataset after EDA:
#         originp  responp  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  \
# 0         38164    50443             1             1                  0
# 1         43068    50443             1             1                  0
# 2          5678     5678             3             0                  3
# 3          5678     5678             2             0                  2
# 4          5678     5678             2             0                  2
# ...         ...      ...           ...           ...                ...
# 228248    53866     1947             2             0                  2
# 228249    54318     1947             2             0                  2
# 228250    65355     1947             2             0                  2
# 228251    53642     1947             2             0                  2
# 228252    61000     1947             2             0                  2
#
#         bwd_data_pkts_tot  bwd_pkts_per_sec  down_up_ratio  \
# 0                       0      16644.063492            1.0
# 1                       0      12052.597701            1.0
# 2                       0          0.000000            0.0
# 3                       0          0.000000            0.0
# 4                       0          0.000000            0.0
# ...                   ...               ...            ...
# 228248                  0          0.000000            0.0
# 228249                  0          0.000000            0.0
# 228250                  0          0.000000            0.0
# 228251                  0          0.000000            0.0
# 228252                  0          0.000000            0.0
#
#         fwd_header_size_tot  fwd_header_size_min  ...  bwd_subflow_bytes  \
# 0                        40                   40  ...                0.0
# 1                        40                   40  ...                0.0
# 2                        24                    8  ...                0.0
# 3                        16                    8  ...                0.0
# 4                        16                    8  ...                0.0
# ...                     ...                  ...  ...                ...
# 228248                   16                    8  ...                0.0
# 228249                   16                    8  ...                0.0
# 228250                   16                    8  ...                0.0
# 228251                   16                    8  ...                0.0
# 228252                   16                    8  ...                0.0
#
#         fwd_bulk_packets  bwd_bulk_packets  active.min  active.max  \
# 0                    0.0               0.0   60.081482   60.081482
# 1                    0.0               0.0   82.969666   82.969666
# 2                    0.0               0.0    0.000000    0.000000
# 3                    0.0               0.0    0.000000    0.000000
# 4                    0.0               0.0    0.000000    0.000000
# ...                  ...               ...         ...         ...
# 228248               0.0               0.0   27.179718   27.179718
# 228249               0.0               0.0   26.941299   26.941299
# 228250               0.0               0.0    0.000000    0.000000
# 228251               0.0               0.0   53.882599   53.882599
# 228252               0.0               0.0    0.000000    0.000000
#
#         active.avg  fwd_init_window_size  bwd_init_window_size  \
# 0        60.081482                 64240                     0
# 1        82.969666                 64240                     0
# 2         0.000000                     0                     0
# 3         0.000000                     0                     0
# 4         0.000000                     0                     0
# ...            ...                   ...                   ...
# 228248   27.179718                     0                     0
# 228249   26.941299                     0                     0
# 228250    0.000000                     0                     0
# 228251   53.882599                     0                     0
# 228252    0.000000                     0                     0
#
#         fwd_last_window_size  Label
# 0                      64240      0
# 1                      64240      0
# 2                          0      0
# 3                          0      0
# 4                          0      0
# ...                      ...    ...
# 228248                     0      1
# 228249                     0      1
# 228250                     0      1
# 228251                     0      1
# 228252                     0      1
#
# [228253 rows x 44 columns]

# %% [markdown]
# ---
#
# ## Models

# %% [markdown]
# ### Without feature extraction

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Cross-validation
def cross_validation(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []

    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Resample with SMOTE 
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
        print("X_train_resampled, ", X_train_resampled.shape)
        print("y_train_resampled, ", y_train_resampled.value_counts())
        
        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train_resampled)
        X_test = scaler.transform(X_test)

        # Train Logistic Regression classifier
        lr_classifier = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)
        lr_classifier.fit(X_train, y_train_resampled)

        # Make predictions
        y_pred = lr_classifier.predict(X_test)

        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")   



tiempo_inicial = time()
#
cross_validation(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# X_train_resampled,  (343860, 43)
# y_train_resampled,  Label
# 0    171930
# 1    171930
# Name: count, dtype: int64
# Fold accuracy: 0.9725307222185713
# Fold precision: 0.6812738853503185
# Fold recall: 0.9988793425476279
# Fold F1-score: 0.810057558315662
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     42974
#            1       0.68      1.00      0.81      2677
#
#     accuracy                           0.97     45651
#    macro avg       0.84      0.98      0.90     45651
# weighted avg       0.98      0.97      0.97     45651
#
# X_train_resampled,  (343952, 43)
# y_train_resampled,  Label
# 0    171976
# 1    171976
# Name: count, dtype: int64
# Fold accuracy: 0.973034544697816
# Fold precision: 0.6894362620619604
# Fold recall: 0.9970620639001102
# Fold F1-score: 0.8151929139768803
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     42928
#            1       0.69      1.00      0.82      2723
#
#     accuracy                           0.97     45651
#    macro avg       0.84      0.98      0.90     45651
# weighted avg       0.98      0.97      0.98     45651
#
# X_train_resampled,  (343710, 43)
# y_train_resampled,  Label
# 0    171855
# 1    171855
# Name: count, dtype: int64
# Fold accuracy: 0.9732535979496616
# Fold precision: 0.6810910044584316
# Fold recall: 0.9980784012298232
# Fold F1-score: 0.8096648480124707
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     43049
#            1       0.68      1.00      0.81      2602
#
#     accuracy                           0.97     45651
#    macro avg       0.84      0.98      0.90     45651
# weighted avg       0.98      0.97      0.98     45651
#
# X_train_resampled,  (343910, 43)
# y_train_resampled,  Label
# 0    171955
# 1    171955
# Name: count, dtype: int64
# Fold accuracy: 0.9716100766703176
# Fold precision: 0.6758448060075094
# Fold recall: 0.9996297667530544
# Fold F1-score: 0.8064516129032258
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     42949
#            1       0.68      1.00      0.81      2701
#
#     accuracy                           0.97     45650
#    macro avg       0.84      0.98      0.90     45650
# weighted avg       0.98      0.97      0.97     45650
#
# X_train_resampled,  (343800, 43)
# y_train_resampled,  Label
# 0    171900
# 1    171900
# Name: count, dtype: int64
# Fold accuracy: 0.972223439211391
# Fold precision: 0.6761247443762781
# Fold recall: 0.9996220710506425
# Fold F1-score: 0.8066483684050015
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     43004
#            1       0.68      1.00      0.81      2646
#
#     accuracy                           0.97     45650
#    macro avg       0.84      0.99      0.90     45650
# weighted avg       0.98      0.97      0.97     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9725304761495515
# Mean precision: 0.6807541404508995
# Mean recall: 0.9986543290962515
# Mean F1-score: 0.8096030603226481
#
# El tiempo de ejecucion fue: 26.359381437301636

# %% [markdown]
# ---
#
# ### With DNN

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the DNN model
def create_dnn(input_dim):
    inputs = Input(shape=(input_dim,))
    
    # Hidden layer 1
    x = Dense(input_dim * 2)(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    # Hidden layer 2
    x = Dense(input_dim)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    # Feature layer
    n_bottleneck = round(float(input_dim) / 2.0)
    bottleneck = Dense(n_bottleneck)(x)
    bottleneck = BatchNormalization()(bottleneck)
    bottleneck = ReLU()(bottleneck)
    
    # Output layer
    outputs = Dense(1, activation='sigmoid')(bottleneck)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    # Model for feature extraction
    feature_extractor = Model(inputs=inputs, outputs=bottleneck)
    
    return model, feature_extractor

# Cross-validation
def cross_validation_dnn(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Resample with SMOTE 
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
        print("X_train_resampled, ", X_train_resampled.shape)
        print("y_train_resampled, ", y_train_resampled.value_counts())
        
        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train_resampled)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        dnn, feature_extractor = create_dnn(n_inputs)
        
        # Early Stopping
        early_stopping1 = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)
        early_stopping2 = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
        
        # Fit the DNN model
        dnn.fit(X_train, y_train_resampled, epochs=100, batch_size=32, verbose=1,
                        validation_data=(X_test, y_test),
                        callbacks=[early_stopping1, early_stopping2])
        
        # Encode the data
        X_train_encoded = feature_extractor.predict(X_train)
        X_test_encoded = feature_extractor.predict(X_test)
        
        # Train Logistic Regression classifier
        lr_classifier_encoded = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)
        lr_classifier_encoded.fit(X_train_encoded, y_train_resampled)
        
        # Make predictions
        y_pred_encoded = lr_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")


tiempo_inicial = time()
#
cross_validation_dnn(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# X_train_resampled,  (343860, 43)
# y_train_resampled,  Label
# 0    171930
# 1    171930
# Name: count, dtype: int64
# Epoch 1/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 9s 755us/step - accuracy: 0.9841 - loss: 0.0641 - val_accuracy: 0.9805 - val_loss: 0.0558
# Epoch 2/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 8s 750us/step - accuracy: 0.9895 - loss: 0.0382 - val_accuracy: 0.9814 - val_loss: 0.0502
# Epoch 3/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 8s 744us/step - accuracy: 0.9898 - loss: 0.0368 - val_accuracy: 0.9812 - val_loss: 0.0497
# Epoch 4/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 8s 754us/step - accuracy: 0.9901 - loss: 0.0359 - val_accuracy: 0.9809 - val_loss: 0.0556
# Epoch 5/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 8s 757us/step - accuracy: 0.9904 - loss: 0.0354 - val_accuracy: 0.9810 - val_loss: 0.0530
# Epoch 6/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 8s 757us/step - accuracy: 0.9904 - loss: 0.0350 - val_accuracy: 0.9815 - val_loss: 0.0540
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 5s 432us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 428us/step
# Fold accuracy: 0.9817309587960833
# Fold precision: 0.7627601938979185
# Fold recall: 0.999252895031752
# Fold F1-score: 0.8651358344113842
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     42974
#            1       0.76      1.00      0.87      2677
#
#     accuracy                           0.98     45651
#    macro avg       0.88      0.99      0.93     45651
# weighted avg       0.99      0.98      0.98     45651
#
# X_train_resampled,  (343952, 43)
# y_train_resampled,  Label
# 0    171976
# 1    171976
# Name: count, dtype: int64
# Epoch 1/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 10s 770us/step - accuracy: 0.9833 - loss: 0.0612 - val_accuracy: 0.9810 - val_loss: 0.0685
# Epoch 2/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 749us/step - accuracy: 0.9894 - loss: 0.0378 - val_accuracy: 0.9816 - val_loss: 0.0549
# Epoch 3/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 752us/step - accuracy: 0.9899 - loss: 0.0364 - val_accuracy: 0.9820 - val_loss: 0.0485
# Epoch 4/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 755us/step - accuracy: 0.9903 - loss: 0.0355 - val_accuracy: 0.9823 - val_loss: 0.0518
# Epoch 5/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 754us/step - accuracy: 0.9900 - loss: 0.0361 - val_accuracy: 0.9821 - val_loss: 0.0478
# Epoch 6/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 752us/step - accuracy: 0.9902 - loss: 0.0354 - val_accuracy: 0.9821 - val_loss: 0.0540
# Epoch 7/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 754us/step - accuracy: 0.9904 - loss: 0.0350 - val_accuracy: 0.9810 - val_loss: 0.0559
# Epoch 8/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 752us/step - accuracy: 0.9904 - loss: 0.0350 - val_accuracy: 0.9389 - val_loss: 0.1174
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 5s 438us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 427us/step
# Fold accuracy: 0.9823662132264354
# Fold precision: 0.7724431818181818
# Fold recall: 0.9985310319500551
# Fold F1-score: 0.8710555822521224
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     42928
#            1       0.77      1.00      0.87      2723
#
#     accuracy                           0.98     45651
#    macro avg       0.89      0.99      0.93     45651
# weighted avg       0.99      0.98      0.98     45651
#
# X_train_resampled,  (343710, 43)
# y_train_resampled,  Label
# 0    171855
# 1    171855
# Name: count, dtype: int64
# Epoch 1/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 10s 776us/step - accuracy: 0.9860 - loss: 0.0561 - val_accuracy: 0.9766 - val_loss: 0.0636
# Epoch 2/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 8s 758us/step - accuracy: 0.9897 - loss: 0.0372 - val_accuracy: 0.9817 - val_loss: 0.0539
# Epoch 3/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 8s 764us/step - accuracy: 0.9895 - loss: 0.0374 - val_accuracy: 0.9811 - val_loss: 0.0533
# Epoch 4/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 8s 759us/step - accuracy: 0.9898 - loss: 0.0368 - val_accuracy: 0.9833 - val_loss: 0.0486
# Epoch 5/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 8s 763us/step - accuracy: 0.9902 - loss: 0.0357 - val_accuracy: 0.9815 - val_loss: 0.0456
# Epoch 6/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 8s 761us/step - accuracy: 0.9904 - loss: 0.0352 - val_accuracy: 0.9829 - val_loss: 0.0498
# Epoch 7/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 8s 766us/step - accuracy: 0.9903 - loss: 0.0352 - val_accuracy: 0.9831 - val_loss: 0.0472
# Epoch 8/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 8s 756us/step - accuracy: 0.9904 - loss: 0.0351 - val_accuracy: 0.9828 - val_loss: 0.0481
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 5s 435us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 441us/step
# Fold accuracy: 0.9830014676567874
# Fold precision: 0.7707591933570581
# Fold recall: 0.9988470407378939
# Fold F1-score: 0.8701037830599263
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     43049
#            1       0.77      1.00      0.87      2602
#
#     accuracy                           0.98     45651
#    macro avg       0.89      0.99      0.93     45651
# weighted avg       0.99      0.98      0.98     45651
#
# X_train_resampled,  (343910, 43)
# y_train_resampled,  Label
# 0    171955
# 1    171955
# Name: count, dtype: int64
# Epoch 1/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 10s 782us/step - accuracy: 0.9833 - loss: 0.0598 - val_accuracy: 0.9796 - val_loss: 0.0617
# Epoch 2/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 776us/step - accuracy: 0.9893 - loss: 0.0381 - val_accuracy: 0.9812 - val_loss: 0.0551
# Epoch 3/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 773us/step - accuracy: 0.9898 - loss: 0.0366 - val_accuracy: 0.9817 - val_loss: 0.0485
# Epoch 4/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 779us/step - accuracy: 0.9906 - loss: 0.0347 - val_accuracy: 0.9805 - val_loss: 0.0647
# Epoch 5/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 774us/step - accuracy: 0.9900 - loss: 0.0360 - val_accuracy: 0.9807 - val_loss: 0.0568
# Epoch 6/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 8s 774us/step - accuracy: 0.9904 - loss: 0.0351 - val_accuracy: 0.9808 - val_loss: 0.0550
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 5s 436us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 452us/step
# Fold accuracy: 0.9818400876232202
# Fold precision: 0.7653061224489796
# Fold recall: 0.9996297667530544
# Fold F1-score: 0.8669128270990528
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     42949
#            1       0.77      1.00      0.87      2701
#
#     accuracy                           0.98     45650
#    macro avg       0.88      0.99      0.93     45650
# weighted avg       0.99      0.98      0.98     45650
#
# X_train_resampled,  (343800, 43)
# y_train_resampled,  Label
# 0    171900
# 1    171900
# Name: count, dtype: int64
# Epoch 1/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 10s 782us/step - accuracy: 0.9823 - loss: 0.0652 - val_accuracy: 0.9796 - val_loss: 0.0541
# Epoch 2/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 8s 776us/step - accuracy: 0.9894 - loss: 0.0385 - val_accuracy: 0.9779 - val_loss: 0.0649
# Epoch 3/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 8s 771us/step - accuracy: 0.9899 - loss: 0.0367 - val_accuracy: 0.9813 - val_loss: 0.0480
# Epoch 4/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 8s 774us/step - accuracy: 0.9899 - loss: 0.0368 - val_accuracy: 0.9814 - val_loss: 0.0545
# Epoch 5/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 8s 773us/step - accuracy: 0.9901 - loss: 0.0360 - val_accuracy: 0.9822 - val_loss: 0.0486
# Epoch 6/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 8s 774us/step - accuracy: 0.9903 - loss: 0.0356 - val_accuracy: 0.9820 - val_loss: 0.0480
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 5s 435us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 432us/step
# Fold accuracy: 0.9816867469879518
# Fold precision: 0.7599080987937966
# Fold recall: 1.0
# Fold F1-score: 0.8635770234986945
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     43004
#            1       0.76      1.00      0.86      2646
#
#     accuracy                           0.98     45650
#    macro avg       0.88      0.99      0.93     45650
# weighted avg       0.99      0.98      0.98     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9821250948580957
# Mean precision: 0.7662353580631869
# Mean recall: 0.9992521468945512
# Mean F1-score: 0.867357010064236
#
# El tiempo de ejecucion fue: 335.31132555007935

# %% [markdown]
# ---
#
# ### With DBN

# %%
def visualize_dbn(layers, file_name='dbn_structure.png'):
    # Crear un grafo dirigido
    G = nx.DiGraph()

    # Añadir nodos para cada capa RBM
    for i, n_units in enumerate(layers):
        G.add_node(f"RBM {i+1}\n{n_units} unidades", layer=i+1)

    # Añadir aristas entre nodos (de una capa a otra)
    for i in range(len(layers) - 1):
        G.add_edge(f"RBM {i+1}\n{layers[i]} unidades", f"RBM {i+2}\n{layers[i+1]} unidades")

    # Dibujar el grafo
    pos = nx.spring_layout(G)  # Posición de los nodos
    nx.draw(G, pos, with_labels=True, node_size=3000, node_color='lightblue', font_size=10, font_weight='bold')
    
    # Guardar la imagen a un archivo
    plt.title("Arquitectura de la DBN")
    plt.savefig(file_name)
    plt.show()
    
#visualize_dbn([X.shape[1]*2, X.shape[1]])

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the DBN class
class DBN(BaseEstimator, TransformerMixin):
    def __init__(self, rbm_layers, rbm_learning_rate, rbm_n_iter):
        self.rbm_layers = rbm_layers
        self.rbm_learning_rate = rbm_learning_rate
        self.rbm_n_iter = rbm_n_iter
        self.rbms = []
        for i, n_components in enumerate(rbm_layers):
            self.rbms.append(BernoulliRBM(n_components=n_components, learning_rate=rbm_learning_rate, n_iter=rbm_n_iter, verbose=1))

    def fit(self, X, y=None):
        input_data = X
        for rbm in self.rbms:
            rbm.fit(input_data)
            input_data = rbm.transform(input_data)
        return self

    def transform(self, X):
        input_data = X
        for rbm in self.rbms:
            input_data = rbm.transform(input_data)
        return input_data

# Cross-validation
def cross_validation_dbn(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Resample with SMOTE 
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
        print("X_train_resampled, ", X_train_resampled.shape)
        print("y_train_resampled, ", y_train_resampled.value_counts())
        
        # Normalize data
        scaler = MinMaxScaler()
        X_train = scaler.fit_transform(X_train_resampled)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        dbn = DBN(rbm_layers=[n_inputs*2, n_inputs], rbm_learning_rate=0.1, rbm_n_iter=10)
        
        # Fit the DBN model
        dbn.fit(X_train)
        
        # Encode the data
        X_train_encoded = dbn.transform(X_train)
        X_test_encoded = dbn.transform(X_test)
        
        # Train Logistic Regression classifier
        lr_classifier_encoded = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)
        lr_classifier_encoded.fit(X_train_encoded, y_train_resampled)
        
        # Make predictions
        y_pred_encoded = lr_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")
    
    
tiempo_inicial = time()
#
cross_validation_dbn(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# X_train_resampled,  (343860, 43)
# y_train_resampled,  Label
# 0    171930
# 1    171930
# Name: count, dtype: int64
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.48, time = 4.56s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.20, time = 5.82s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.91, time = 5.85s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.95, time = 5.78s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -5.06, time = 5.76s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.89, time = 5.82s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.90, time = 5.74s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -5.04, time = 5.92s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.88, time = 5.95s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.90, time = 5.71s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.07, time = 4.34s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.09, time = 5.26s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.41, time = 5.18s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.12, time = 5.15s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -6.70, time = 5.20s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.16, time = 5.25s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.84, time = 5.18s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.04, time = 5.29s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.39, time = 5.15s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -5.35, time = 5.29s
# Fold accuracy: 0.9200674684015684
# Fold precision: 0.3815789473684211
# Fold recall: 0.5849831901382144
# Fold F1-score: 0.46187877894115914
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96     42974
#            1       0.38      0.58      0.46      2677
#
#     accuracy                           0.92     45651
#    macro avg       0.68      0.76      0.71     45651
# weighted avg       0.94      0.92      0.93     45651
#
# X_train_resampled,  (343952, 43)
# y_train_resampled,  Label
# 0    171976
# 1    171976
# Name: count, dtype: int64
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.44, time = 4.66s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.35, time = 5.87s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.16, time = 5.94s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.09, time = 5.90s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.92, time = 5.79s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.94, time = 5.80s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -5.13, time = 5.78s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -5.01, time = 5.79s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -5.04, time = 5.89s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -5.18, time = 5.86s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -3.39, time = 4.39s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -3.39, time = 5.35s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -3.53, time = 5.13s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -3.45, time = 5.22s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -3.49, time = 5.34s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -3.33, time = 5.28s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -3.71, time = 5.19s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -3.47, time = 5.28s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -3.63, time = 5.19s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -3.37, time = 5.12s
# Fold accuracy: 0.9249304505925391
# Fold precision: 0.4090909090909091
# Fold recall: 0.5817113477781858
# Fold F1-score: 0.4803639120545868
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96     42928
#            1       0.41      0.58      0.48      2723
#
#     accuracy                           0.92     45651
#    macro avg       0.69      0.76      0.72     45651
# weighted avg       0.94      0.92      0.93     45651
#
# X_train_resampled,  (343710, 43)
# y_train_resampled,  Label
# 0    171855
# 1    171855
# Name: count, dtype: int64
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.54, time = 4.59s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.41, time = 5.82s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.20, time = 5.91s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.16, time = 5.75s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -5.24, time = 5.78s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -5.16, time = 5.89s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -5.03, time = 5.91s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -5.28, time = 5.73s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -5.08, time = 5.85s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -5.07, time = 5.81s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -3.53, time = 4.42s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -3.43, time = 5.31s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -3.44, time = 5.20s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -3.54, time = 5.15s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -3.76, time = 5.21s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -3.56, time = 5.22s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -3.36, time = 5.23s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -3.68, time = 5.25s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -3.45, time = 5.15s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -3.49, time = 5.19s
# Fold accuracy: 0.9180959891349587
# Fold precision: 0.3582647718773373
# Fold recall: 0.5522674865488086
# Fold F1-score: 0.4345985180704673
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96     43049
#            1       0.36      0.55      0.43      2602
#
#     accuracy                           0.92     45651
#    macro avg       0.67      0.75      0.70     45651
# weighted avg       0.94      0.92      0.93     45651
#
# X_train_resampled,  (343910, 43)
# y_train_resampled,  Label
# 0    171955
# 1    171955
# Name: count, dtype: int64
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.51, time = 4.63s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.34, time = 5.90s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.14, time = 6.05s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.06, time = 5.83s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -5.01, time = 5.80s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -5.04, time = 5.83s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.92, time = 5.80s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -5.13, time = 5.78s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.97, time = 5.86s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -5.03, time = 5.83s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.94, time = 4.51s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.32, time = 5.22s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.95, time = 5.19s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.45, time = 5.22s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -3.64, time = 5.16s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -3.78, time = 5.07s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -3.20, time = 5.29s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.10, time = 5.24s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -3.46, time = 5.26s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -3.38, time = 5.34s
# Fold accuracy: 0.9238992332968237
# Fold precision: 0.39836970812516437
# Fold recall: 0.5609033691225472
# Fold F1-score: 0.46586715867158673
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96     42949
#            1       0.40      0.56      0.47      2701
#
#     accuracy                           0.92     45650
#    macro avg       0.69      0.75      0.71     45650
# weighted avg       0.94      0.92      0.93     45650
#
# X_train_resampled,  (343800, 43)
# y_train_resampled,  Label
# 0    171900
# 1    171900
# Name: count, dtype: int64
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.30, time = 4.70s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.21, time = 5.83s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.00, time = 6.01s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.86, time = 5.85s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.97, time = 5.82s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -5.02, time = 5.87s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.93, time = 5.73s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.97, time = 5.89s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.86, time = 5.75s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.97, time = 5.87s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.10, time = 4.64s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.07, time = 5.18s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -3.98, time = 5.22s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.11, time = 5.28s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.32, time = 5.21s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -5.74, time = 5.16s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -3.95, time = 5.34s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -7.12, time = 5.15s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.79, time = 5.21s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -6.07, time = 5.27s
# Fold accuracy: 0.9261774370208106
# Fold precision: 0.40247844827586204
# Fold recall: 0.564625850340136
# Fold F1-score: 0.46995910663730733
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96     43004
#            1       0.40      0.56      0.47      2646
#
#     accuracy                           0.93     45650
#    macro avg       0.69      0.76      0.72     45650
# weighted avg       0.94      0.93      0.93     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9226341156893401
# Mean precision: 0.3899565569475388
# Mean recall: 0.5688982487855785
# Mean F1-score: 0.4625334948750215
#
# El tiempo de ejecucion fue: 565.5910074710846

# %% [markdown]
# ---
#
# ### With Autoencoder

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the autoencoder model
def create_autoencoder(n_inputs):
    inputs = Input(shape=(n_inputs,))
    
    # Define Encoder
    e = Dense(n_inputs*2)(inputs)
    e = BatchNormalization()(e)
    e = LeakyReLU()(e)
    
    # Bottleneck
    n_bottleneck = round(float(n_inputs)/2.0)
    bottleneck = Dense(n_bottleneck)(e)
    
    # Define Decoder
    d = Dense(n_inputs*2)(bottleneck)
    d = BatchNormalization()(d)
    d = LeakyReLU()(d)
    
    # Output layer
    outputs = Dense(n_inputs, activation='linear')(d)
    
    # Define autoencoder model
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='mse')
    
    # Define encoder model
    encoder = Model(inputs=inputs, outputs=bottleneck)
    
    return model, encoder

# Cross-validation
def cross_validation_autoencoder(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Resample with SMOTE 
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
        print("X_train_resampled, ", X_train_resampled.shape)
        print("y_train_resampled, ", y_train_resampled.value_counts())
        
        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train_resampled)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        autoencoder, encoder = create_autoencoder(n_inputs)
        
        # Early Stopping
        early_stopping1 = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)
        early_stopping2 = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
        
        # Fit the DNN model
        autoencoder.fit(X_train, X_train, epochs=100, batch_size=32, verbose=1,
                        validation_data=(X_test, X_test),
                        callbacks=[early_stopping1, early_stopping2])
        
        # Encode the data
        X_train_encoded = encoder.predict(X_train)
        X_test_encoded = encoder.predict(X_test)
        
        # Train Logistic Regression classifier
        lr_classifier_encoded = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)
        lr_classifier_encoded.fit(X_train_encoded, y_train_resampled)
        
        # Make predictions
        y_pred_encoded = lr_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")


tiempo_inicial = time()
#
cross_validation_autoencoder(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# X_train_resampled,  (343860, 43)
# y_train_resampled,  Label
# 0    171930
# 1    171930
# Name: count, dtype: int64
# Epoch 1/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 9s 688us/step - loss: 0.1553 - val_loss: 0.1248
# Epoch 2/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 684us/step - loss: 0.0784 - val_loss: 0.0536
# Epoch 3/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 669us/step - loss: 0.0931 - val_loss: 0.0469
# Epoch 4/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 672us/step - loss: 0.0833 - val_loss: 0.0518
# Epoch 5/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 669us/step - loss: 0.0678 - val_loss: 0.0360
# Epoch 6/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 672us/step - loss: 0.0557 - val_loss: 0.0376
# Epoch 7/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 669us/step - loss: 0.0450 - val_loss: 0.0337
# Epoch 8/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 671us/step - loss: 0.0486 - val_loss: 0.0663
# Epoch 9/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 670us/step - loss: 0.0497 - val_loss: 0.0299
# Epoch 10/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 670us/step - loss: 0.0591 - val_loss: 0.0303
# Epoch 11/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 673us/step - loss: 0.0449 - val_loss: 0.0327
# Epoch 12/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 666us/step - loss: 0.0342 - val_loss: 0.0272
# Epoch 13/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 669us/step - loss: 0.0336 - val_loss: 0.0332
# Epoch 14/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 667us/step - loss: 0.0463 - val_loss: 0.0576
# Epoch 15/100
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 7s 669us/step - loss: 0.0327 - val_loss: 0.0627
# 10746/10746 ━━━━━━━━━━━━━━━━━━━━ 4s 396us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 397us/step
# Fold accuracy: 0.9697268405949486
# Fold precision: 0.6597582037996546
# Fold recall: 0.9988793425476279
# Fold F1-score: 0.7946508172362555
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     42974
#            1       0.66      1.00      0.79      2677
#
#     accuracy                           0.97     45651
#    macro avg       0.83      0.98      0.89     45651
# weighted avg       0.98      0.97      0.97     45651
#
# X_train_resampled,  (343952, 43)
# y_train_resampled,  Label
# 0    171976
# 1    171976
# Name: count, dtype: int64
# Epoch 1/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 8s 669us/step - loss: 0.1808 - val_loss: 0.1425
# Epoch 2/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 661us/step - loss: 0.0997 - val_loss: 0.2523
# Epoch 3/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 661us/step - loss: 0.1102 - val_loss: 0.0540
# Epoch 4/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 662us/step - loss: 0.0502 - val_loss: 0.0622
# Epoch 5/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 666us/step - loss: 0.0668 - val_loss: 0.1131
# Epoch 6/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 661us/step - loss: 0.0522 - val_loss: 0.0499
# Epoch 7/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 662us/step - loss: 0.0468 - val_loss: 0.0473
# Epoch 8/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 665us/step - loss: 0.0349 - val_loss: 0.0894
# Epoch 9/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 664us/step - loss: 0.0406 - val_loss: 0.0387
# Epoch 10/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 664us/step - loss: 0.0437 - val_loss: 0.0415
# Epoch 11/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 667us/step - loss: 0.0428 - val_loss: 0.0845
# Epoch 12/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 668us/step - loss: 0.0573 - val_loss: 0.0364
# Epoch 13/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 669us/step - loss: 0.0702 - val_loss: 0.0483
# Epoch 14/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 670us/step - loss: 0.0307 - val_loss: 0.0745
# Epoch 15/100
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 7s 666us/step - loss: 0.0383 - val_loss: 0.0435
# 10749/10749 ━━━━━━━━━━━━━━━━━━━━ 4s 397us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 398us/step
# Fold accuracy: 0.9701649470986397
# Fold precision: 0.6674046740467404
# Fold recall: 0.9963275798751378
# Fold F1-score: 0.7993517972893341
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     42928
#            1       0.67      1.00      0.80      2723
#
#     accuracy                           0.97     45651
#    macro avg       0.83      0.98      0.89     45651
# weighted avg       0.98      0.97      0.97     45651
#
# X_train_resampled,  (343710, 43)
# y_train_resampled,  Label
# 0    171855
# 1    171855
# Name: count, dtype: int64
# Epoch 1/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 8s 669us/step - loss: 0.1805 - val_loss: 0.5259
# Epoch 2/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 7s 665us/step - loss: 0.0865 - val_loss: 0.4972
# Epoch 3/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 7s 666us/step - loss: 0.0649 - val_loss: 0.5948
# Epoch 4/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 7s 667us/step - loss: 0.0774 - val_loss: 0.3749
# Epoch 5/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 7s 659us/step - loss: 0.0473 - val_loss: 0.4965
# Epoch 6/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 7s 668us/step - loss: 0.0456 - val_loss: 0.4996
# Epoch 7/100
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 7s 661us/step - loss: 0.0342 - val_loss: 0.4759
# 10741/10741 ━━━━━━━━━━━━━━━━━━━━ 4s 400us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 398us/step
# Fold accuracy: 0.9719173731134039
# Fold precision: 0.6702786377708978
# Fold recall: 0.9984627209838586
# Fold F1-score: 0.8020994133991973
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     43049
#            1       0.67      1.00      0.80      2602
#
#     accuracy                           0.97     45651
#    macro avg       0.84      0.98      0.89     45651
# weighted avg       0.98      0.97      0.97     45651
#
# X_train_resampled,  (343910, 43)
# y_train_resampled,  Label
# 0    171955
# 1    171955
# Name: count, dtype: int64
# Epoch 1/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 9s 675us/step - loss: 0.1713 - val_loss: 0.0846
# Epoch 2/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 7s 674us/step - loss: 0.1192 - val_loss: 0.0607
# Epoch 3/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 7s 669us/step - loss: 0.0832 - val_loss: 0.0887
# Epoch 4/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 7s 672us/step - loss: 0.0661 - val_loss: 0.0812
# Epoch 5/100
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 7s 668us/step - loss: 0.0415 - val_loss: 0.1490
# 10748/10748 ━━━━━━━━━━━━━━━━━━━━ 4s 401us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 402us/step
# Fold accuracy: 0.9684118291347207
# Fold precision: 0.6520898767818314
# Fold recall: 0.9992595335061089
# Fold F1-score: 0.7891812865497077
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     42949
#            1       0.65      1.00      0.79      2701
#
#     accuracy                           0.97     45650
#    macro avg       0.83      0.98      0.89     45650
# weighted avg       0.98      0.97      0.97     45650
#
# X_train_resampled,  (343800, 43)
# y_train_resampled,  Label
# 0    171900
# 1    171900
# Name: count, dtype: int64
# Epoch 1/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 8s 671us/step - loss: 0.2036 - val_loss: 0.8367
# Epoch 2/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 7s 664us/step - loss: 0.0824 - val_loss: 0.4435
# Epoch 3/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 7s 656us/step - loss: 0.0735 - val_loss: 0.1282
# Epoch 4/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 7s 660us/step - loss: 0.0516 - val_loss: 0.1326
# Epoch 5/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 7s 657us/step - loss: 0.0674 - val_loss: 0.6362
# Epoch 6/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 7s 662us/step - loss: 0.0736 - val_loss: 0.0307
# Epoch 7/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 7s 657us/step - loss: 0.0481 - val_loss: 0.2564
# Epoch 8/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 7s 657us/step - loss: 0.0461 - val_loss: 0.0653
# Epoch 9/100
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 7s 660us/step - loss: 0.0391 - val_loss: 0.1762
# 10744/10744 ━━━━━━━━━━━━━━━━━━━━ 4s 398us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 400us/step
# Fold accuracy: 0.9689594742606791
# Fold precision: 0.651317409505048
# Fold recall: 0.9996220710506425
# Fold F1-score: 0.7887281944237364
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     43004
#            1       0.65      1.00      0.79      2646
#
#     accuracy                           0.97     45650
#    macro avg       0.83      0.98      0.89     45650
# weighted avg       0.98      0.97      0.97     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9698360928404786
# Mean precision: 0.6601697603808345
# Mean recall: 0.9985102495926752
# Mean F1-score: 0.7948023017796462
#
# El tiempo de ejecucion fue: 429.91396474838257
