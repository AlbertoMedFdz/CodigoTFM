# %% [markdown]
# _Alberto Medrano Fernández_
#
# # AdaBoost

# %% [markdown]
# ---
#
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from time import time

from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler, LabelEncoder 
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.ensemble import AdaBoostClassifier
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.neural_network import BernoulliRBM
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

from tensorflow.keras.models import load_model, Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Input, Dense, BatchNormalization, ReLU, LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ---
#
# ## Dataset

# %%
hikari_2022 = pd.read_csv('ALLFLOWMETER_HIKARI2022.csv', sep=',')
hikari_2022
# Out:
#         Unnamed: 0                 uid       originh  originp  \
# 0                0  Cmu9v81jToQyRF1gbk  184.0.48.168    38164
# 1                1  CO21hl3TWkuXTOgajk  184.0.48.169    43068
# 2                2  CBLJ6L19FP0MfYX7Oh  184.0.48.124     5678
# 3                3  ChTG451zJ7hUYOcqje  184.0.48.124     5678
# 4                4  Cn9y6E2KVxzQbs5wjc  184.0.48.124     5678
# ...            ...                 ...           ...      ...
# 228248       16634   Clt16PPxzrXEtpa5d   184.0.48.20    53866
# 228249       53170  Cs8RA72uHDiQa5ch2k   184.0.48.20    54318
# 228250       53529  Cy4dqo4YEq5YGxjUXa   184.0.48.20    65355
# 228251       86308  CFXfNV3OTG04e0UnP4   184.0.48.20    53642
# 228252       99240  CqO7kc2eC5InNvWrtl   184.0.48.20    61000
#
#                 responh  responp           flow_duration  fwd_pkts_tot  \
# 0          184.0.48.150    50443  0 days 00:00:00.000060             1
# 1          184.0.48.150    50443  0 days 00:00:00.000083             1
# 2       255.255.255.255     5678  0 days 00:01:59.996602             3
# 3       255.255.255.255     5678  0 days 00:00:59.996909             2
# 4       255.255.255.255     5678  0 days 00:00:59.992130             2
# ...                 ...      ...                     ...           ...
# 228248     184.0.48.255     1947  0 days 00:00:00.000027             2
# 228249     184.0.48.255     1947  0 days 00:00:00.000027             2
# 228250     184.0.48.255     1947         0 days 00:00:00             2
# 228251     184.0.48.255     1947  0 days 00:00:00.000054             2
# 228252     184.0.48.255     1947         0 days 00:00:00             2
#
#         bwd_pkts_tot  fwd_data_pkts_tot  ...      idle.max      idle.tot  \
# 0                  1                  0  ...  0.000000e+00  0.000000e+00
# 1                  1                  0  ...  0.000000e+00  0.000000e+00
# 2                  0                  3  ...  5.999912e+07  1.199966e+08
# 3                  0                  2  ...  5.999691e+07  5.999691e+07
# 4                  0                  2  ...  5.999213e+07  5.999213e+07
# ...              ...                ...  ...           ...           ...
# 228248             0                  2  ...  0.000000e+00  0.000000e+00
# 228249             0                  2  ...  0.000000e+00  0.000000e+00
# 228250             0                  2  ...  0.000000e+00  0.000000e+00
# 228251             0                  2  ...  0.000000e+00  0.000000e+00
# 228252             0                  2  ...  0.000000e+00  0.000000e+00
#
#             idle.avg     idle.std  fwd_init_window_size  bwd_init_window_size  \
# 0       0.000000e+00     0.000000                 64240                     0
# 1       0.000000e+00     0.000000                 64240                     0
# 2       5.999830e+07  1156.846698                     0                     0
# 3       5.999691e+07     0.000000                     0                     0
# 4       5.999213e+07     0.000000                     0                     0
# ...              ...          ...                   ...                   ...
# 228248  0.000000e+00     0.000000                     0                     0
# 228249  0.000000e+00     0.000000                     0                     0
# 228250  0.000000e+00     0.000000                     0                     0
# 228251  0.000000e+00     0.000000                     0                     0
# 228252  0.000000e+00     0.000000                     0                     0
#
#         fwd_last_window_size  bwd_last_window_size      attack_category  Label
# 0                      64240                     0               Benign      0
# 1                      64240                     0               Benign      0
# 2                          0                     0               Benign      0
# 3                          0                     0               Benign      0
# 4                          0                     0               Benign      0
# ...                      ...                   ...                  ...    ...
# 228248                     0                     0  XMRIGCC CryptoMiner      1
# 228249                     0                     0  XMRIGCC CryptoMiner      1
# 228250                     0                     0  XMRIGCC CryptoMiner      1
# 228251                     0                     0  XMRIGCC CryptoMiner      1
# 228252                     0                     0  XMRIGCC CryptoMiner      1
#
# [228253 rows x 88 columns]

# %%
hikari_2022 = hikari_2022.drop(columns=['Unnamed: 0', 'uid', 'originh', 'responh', 'flow_duration', 'fwd_URG_flag_count', 
                                        'bwd_URG_flag_count', 'attack_category'])
hikari_2022
# Out:
#         originp  responp  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  \
# 0         38164    50443             1             1                  0
# 1         43068    50443             1             1                  0
# 2          5678     5678             3             0                  3
# 3          5678     5678             2             0                  2
# 4          5678     5678             2             0                  2
# ...         ...      ...           ...           ...                ...
# 228248    53866     1947             2             0                  2
# 228249    54318     1947             2             0                  2
# 228250    65355     1947             2             0                  2
# 228251    53642     1947             2             0                  2
# 228252    61000     1947             2             0                  2
#
#         bwd_data_pkts_tot  fwd_pkts_per_sec  bwd_pkts_per_sec  \
# 0                       0      16644.063492      16644.063492
# 1                       0      12052.597701      12052.597701
# 2                       0          0.025001          0.000000
# 3                       0          0.033335          0.000000
# 4                       0          0.033338          0.000000
# ...                   ...               ...               ...
# 228248                  0      73584.280702          0.000000
# 228249                  0      74235.469027          0.000000
# 228250                  0          0.000000          0.000000
# 228251                  0      37117.734513          0.000000
# 228252                  0          0.000000          0.000000
#
#         flow_pkts_per_sec  down_up_ratio  ...      idle.min      idle.max  \
# 0            33288.126984            1.0  ...  0.000000e+00  0.000000e+00
# 1            24105.195402            1.0  ...  0.000000e+00  0.000000e+00
# 2                0.025001            0.0  ...  5.999748e+07  5.999912e+07
# 3                0.033335            0.0  ...  5.999691e+07  5.999691e+07
# 4                0.033338            0.0  ...  5.999213e+07  5.999213e+07
# ...                   ...            ...  ...           ...           ...
# 228248       73584.280702            0.0  ...  0.000000e+00  0.000000e+00
# 228249       74235.469027            0.0  ...  0.000000e+00  0.000000e+00
# 228250           0.000000            0.0  ...  0.000000e+00  0.000000e+00
# 228251       37117.734513            0.0  ...  0.000000e+00  0.000000e+00
# 228252           0.000000            0.0  ...  0.000000e+00  0.000000e+00
#
#             idle.tot      idle.avg     idle.std  fwd_init_window_size  \
# 0       0.000000e+00  0.000000e+00     0.000000                 64240
# 1       0.000000e+00  0.000000e+00     0.000000                 64240
# 2       1.199966e+08  5.999830e+07  1156.846698                     0
# 3       5.999691e+07  5.999691e+07     0.000000                     0
# 4       5.999213e+07  5.999213e+07     0.000000                     0
# ...              ...           ...          ...                   ...
# 228248  0.000000e+00  0.000000e+00     0.000000                     0
# 228249  0.000000e+00  0.000000e+00     0.000000                     0
# 228250  0.000000e+00  0.000000e+00     0.000000                     0
# 228251  0.000000e+00  0.000000e+00     0.000000                     0
# 228252  0.000000e+00  0.000000e+00     0.000000                     0
#
#         bwd_init_window_size  fwd_last_window_size  bwd_last_window_size  \
# 0                          0                 64240                     0
# 1                          0                 64240                     0
# 2                          0                     0                     0
# 3                          0                     0                     0
# 4                          0                     0                     0
# ...                      ...                   ...                   ...
# 228248                     0                     0                     0
# 228249                     0                     0                     0
# 228250                     0                     0                     0
# 228251                     0                     0                     0
# 228252                     0                     0                     0
#
#         Label
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 228248      1
# 228249      1
# 228250      1
# 228251      1
# 228252      1
#
# [228253 rows x 80 columns]

# %%
# Calculate Pearson correlation coefficient
corr = hikari_2022.corr(method ='pearson')

# Extract the correlation with the target variable 'Label'
corr_with_target = corr['Label']

# Select only columns with a correlation less than 0.05
relevant_features = corr_with_target[abs(corr_with_target) >= 0.05].index

# Filter the DataFrame to keep only the relevant features
hikari_2022 = hikari_2022[relevant_features]

print("Dataset after EDA:")
hikari_2022
# Out:
# Dataset after EDA:
#         originp  responp  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  \
# 0         38164    50443             1             1                  0
# 1         43068    50443             1             1                  0
# 2          5678     5678             3             0                  3
# 3          5678     5678             2             0                  2
# 4          5678     5678             2             0                  2
# ...         ...      ...           ...           ...                ...
# 228248    53866     1947             2             0                  2
# 228249    54318     1947             2             0                  2
# 228250    65355     1947             2             0                  2
# 228251    53642     1947             2             0                  2
# 228252    61000     1947             2             0                  2
#
#         bwd_data_pkts_tot  bwd_pkts_per_sec  down_up_ratio  \
# 0                       0      16644.063492            1.0
# 1                       0      12052.597701            1.0
# 2                       0          0.000000            0.0
# 3                       0          0.000000            0.0
# 4                       0          0.000000            0.0
# ...                   ...               ...            ...
# 228248                  0          0.000000            0.0
# 228249                  0          0.000000            0.0
# 228250                  0          0.000000            0.0
# 228251                  0          0.000000            0.0
# 228252                  0          0.000000            0.0
#
#         fwd_header_size_tot  fwd_header_size_min  ...  bwd_subflow_bytes  \
# 0                        40                   40  ...                0.0
# 1                        40                   40  ...                0.0
# 2                        24                    8  ...                0.0
# 3                        16                    8  ...                0.0
# 4                        16                    8  ...                0.0
# ...                     ...                  ...  ...                ...
# 228248                   16                    8  ...                0.0
# 228249                   16                    8  ...                0.0
# 228250                   16                    8  ...                0.0
# 228251                   16                    8  ...                0.0
# 228252                   16                    8  ...                0.0
#
#         fwd_bulk_packets  bwd_bulk_packets  active.min  active.max  \
# 0                    0.0               0.0   60.081482   60.081482
# 1                    0.0               0.0   82.969666   82.969666
# 2                    0.0               0.0    0.000000    0.000000
# 3                    0.0               0.0    0.000000    0.000000
# 4                    0.0               0.0    0.000000    0.000000
# ...                  ...               ...         ...         ...
# 228248               0.0               0.0   27.179718   27.179718
# 228249               0.0               0.0   26.941299   26.941299
# 228250               0.0               0.0    0.000000    0.000000
# 228251               0.0               0.0   53.882599   53.882599
# 228252               0.0               0.0    0.000000    0.000000
#
#         active.avg  fwd_init_window_size  bwd_init_window_size  \
# 0        60.081482                 64240                     0
# 1        82.969666                 64240                     0
# 2         0.000000                     0                     0
# 3         0.000000                     0                     0
# 4         0.000000                     0                     0
# ...            ...                   ...                   ...
# 228248   27.179718                     0                     0
# 228249   26.941299                     0                     0
# 228250    0.000000                     0                     0
# 228251   53.882599                     0                     0
# 228252    0.000000                     0                     0
#
#         fwd_last_window_size  Label
# 0                      64240      0
# 1                      64240      0
# 2                          0      0
# 3                          0      0
# 4                          0      0
# ...                      ...    ...
# 228248                     0      1
# 228249                     0      1
# 228250                     0      1
# 228251                     0      1
# 228252                     0      1
#
# [228253 rows x 44 columns]

# %% [markdown]
# ---
#
# ## Models

# %% [markdown]
# ### Without feature extraction

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Cross-validation
def cross_validation(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []

    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        # Train AdaBoost classifier
        ab_classifier = AdaBoostClassifier(n_estimators=100, algorithm='SAMME', random_state=42)
        ab_classifier.fit(X_train, y_train)

        # Make predictions
        y_pred = ab_classifier.predict(X_test)

        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")   



tiempo_inicial = time()
#
cross_validation(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# Fold accuracy: 0.9841405445663841
# Fold precision: 0.994931576279777
# Fold recall: 0.7332835263354501
# Fold F1-score: 0.8443010752688173
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     42974
#            1       0.99      0.73      0.84      2677
#
#     accuracy                           0.98     45651
#    macro avg       0.99      0.87      0.92     45651
# weighted avg       0.98      0.98      0.98     45651
#
# Fold accuracy: 0.9828262250553109
# Fold precision: 0.9869412355600201
# Fold recall: 0.7216305545354389
# Fold F1-score: 0.8336868901145524
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     42928
#            1       0.99      0.72      0.83      2723
#
#     accuracy                           0.98     45651
#    macro avg       0.98      0.86      0.91     45651
# weighted avg       0.98      0.98      0.98     45651
#
# Fold accuracy: 0.9845348404197061
# Fold precision: 0.9851586489252815
# Fold recall: 0.739815526518063
# Fold F1-score: 0.8450395083406497
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     43049
#            1       0.99      0.74      0.85      2602
#
#     accuracy                           0.98     45651
#    macro avg       0.98      0.87      0.92     45651
# weighted avg       0.98      0.98      0.98     45651
#
# Fold accuracy: 0.984118291347207
# Fold precision: 0.9900793650793651
# Fold recall: 0.7389855609033691
# Fold F1-score: 0.8463006147975408
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     42949
#            1       0.99      0.74      0.85      2701
#
#     accuracy                           0.98     45650
#    macro avg       0.99      0.87      0.92     45650
# weighted avg       0.98      0.98      0.98     45650
#
# Fold accuracy: 0.9847535596933187
# Fold precision: 0.993920972644377
# Fold recall: 0.7414965986394558
# Fold F1-score: 0.8493506493506493
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     43004
#            1       0.99      0.74      0.85      2646
#
#     accuracy                           0.98     45650
#    macro avg       0.99      0.87      0.92     45650
# weighted avg       0.98      0.98      0.98     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9840746922163852
# Mean precision: 0.9902063596977643
# Mean recall: 0.7350423533863555
# Mean F1-score: 0.8437357475744418
#
# El tiempo de ejecucion fue: 102.0820083618164

# %% [markdown]
# ---
#
# ### With DNN

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the DNN model
def create_dnn(input_dim):
    inputs = Input(shape=(input_dim,))
    
    # Hidden layer 1
    x = Dense(input_dim * 2)(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    # Hidden layer 2
    x = Dense(input_dim)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    # Feature layer
    n_bottleneck = round(float(input_dim) / 2.0)
    bottleneck = Dense(n_bottleneck)(x)
    bottleneck = BatchNormalization()(bottleneck)
    bottleneck = ReLU()(bottleneck)
    
    # Output layer
    outputs = Dense(1, activation='sigmoid')(bottleneck)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    # Model for feature extraction
    feature_extractor = Model(inputs=inputs, outputs=bottleneck)
    
    return model, feature_extractor

# Cross-validation
def cross_validation_dnn(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        dnn, feature_extractor = create_dnn(n_inputs)
        
        # Early Stopping
        early_stopping1 = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)
        early_stopping2 = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
        
        # Fit the DNN model
        dnn.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1,
                        validation_data=(X_test, y_test),
                        callbacks=[early_stopping1, early_stopping2])
        
        # Encode the data
        X_train_encoded = feature_extractor.predict(X_train)
        X_test_encoded = feature_extractor.predict(X_test)
        
        # Train AdaBoost classifier
        ab_classifier_encoded = AdaBoostClassifier(n_estimators=100, algorithm='SAMME', random_state=42)
        ab_classifier_encoded.fit(X_train_encoded, y_train)
        
        # Make predictions
        y_pred_encoded = ab_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")


tiempo_inicial = time()
#
cross_validation_dnn(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 848us/step - accuracy: 0.9786 - loss: 0.0622 - val_accuracy: 0.9827 - val_loss: 0.0265
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 825us/step - accuracy: 0.9838 - loss: 0.0263 - val_accuracy: 0.9843 - val_loss: 0.0250
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 827us/step - accuracy: 0.9837 - loss: 0.0262 - val_accuracy: 0.9842 - val_loss: 0.0243
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 826us/step - accuracy: 0.9846 - loss: 0.0239 - val_accuracy: 0.9842 - val_loss: 0.0250
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 825us/step - accuracy: 0.9844 - loss: 0.0244 - val_accuracy: 0.9831 - val_loss: 0.0242
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 830us/step - accuracy: 0.9840 - loss: 0.0246 - val_accuracy: 0.9836 - val_loss: 0.0249
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 828us/step - accuracy: 0.9847 - loss: 0.0238 - val_accuracy: 0.9832 - val_loss: 0.0235
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 826us/step - accuracy: 0.9845 - loss: 0.0240 - val_accuracy: 0.9842 - val_loss: 0.0240
# Epoch 9/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 830us/step - accuracy: 0.9845 - loss: 0.0232 - val_accuracy: 0.9841 - val_loss: 0.0252
# Epoch 10/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 827us/step - accuracy: 0.9849 - loss: 0.0232 - val_accuracy: 0.9844 - val_loss: 0.0238
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 454us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 446us/step
# Fold accuracy: 0.9842500711923069
# Fold precision: 1.0
# Fold recall: 0.73141576391483
# Fold F1-score: 0.8448759439050701
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     42974
#            1       1.00      0.73      0.84      2677
#
#     accuracy                           0.98     45651
#    macro avg       0.99      0.87      0.92     45651
# weighted avg       0.98      0.98      0.98     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 844us/step - accuracy: 0.9609 - loss: 0.1032 - val_accuracy: 0.9820 - val_loss: 0.0275
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 828us/step - accuracy: 0.9842 - loss: 0.0264 - val_accuracy: 0.9835 - val_loss: 0.0263
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 825us/step - accuracy: 0.9846 - loss: 0.0245 - val_accuracy: 0.9835 - val_loss: 0.0253
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 825us/step - accuracy: 0.9848 - loss: 0.0239 - val_accuracy: 0.9833 - val_loss: 0.0267
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 826us/step - accuracy: 0.9849 - loss: 0.0234 - val_accuracy: 0.9820 - val_loss: 0.0314
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 833us/step - accuracy: 0.9851 - loss: 0.0232 - val_accuracy: 0.9837 - val_loss: 0.0243
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 827us/step - accuracy: 0.9850 - loss: 0.0233 - val_accuracy: 0.9836 - val_loss: 0.0244
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 827us/step - accuracy: 0.9848 - loss: 0.0237 - val_accuracy: 0.9834 - val_loss: 0.0266
# Epoch 9/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 851us/step - accuracy: 0.9851 - loss: 0.0234 - val_accuracy: 0.9837 - val_loss: 0.0241
# Epoch 10/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 830us/step - accuracy: 0.9848 - loss: 0.0233 - val_accuracy: 0.9837 - val_loss: 0.0243
# Epoch 11/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 824us/step - accuracy: 0.9851 - loss: 0.0234 - val_accuracy: 0.9837 - val_loss: 0.0247
# Epoch 12/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 835us/step - accuracy: 0.9853 - loss: 0.0226 - val_accuracy: 0.9838 - val_loss: 0.0245
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 457us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 450us/step
# Fold accuracy: 0.9837024380626931
# Fold precision: 1.0
# Fold recall: 0.726771942710246
# Fold F1-score: 0.8417694598043386
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     42928
#            1       1.00      0.73      0.84      2723
#
#     accuracy                           0.98     45651
#    macro avg       0.99      0.86      0.92     45651
# weighted avg       0.98      0.98      0.98     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 846us/step - accuracy: 0.9784 - loss: 0.0615 - val_accuracy: 0.9852 - val_loss: 0.0242
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 836us/step - accuracy: 0.9835 - loss: 0.0265 - val_accuracy: 0.9837 - val_loss: 0.0262
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 829us/step - accuracy: 0.9846 - loss: 0.0241 - val_accuracy: 0.9835 - val_loss: 0.0281
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 829us/step - accuracy: 0.9840 - loss: 0.0258 - val_accuracy: 0.9852 - val_loss: 0.0257
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 452us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 444us/step
# Fold accuracy: 0.9851920001752426
# Fold precision: 0.9948612538540597
# Fold recall: 0.744043043812452
# Fold F1-score: 0.851363236587511
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     43049
#            1       0.99      0.74      0.85      2602
#
#     accuracy                           0.99     45651
#    macro avg       0.99      0.87      0.92     45651
# weighted avg       0.99      0.99      0.98     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 860us/step - accuracy: 0.9697 - loss: 0.0877 - val_accuracy: 0.9844 - val_loss: 0.0254
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 843us/step - accuracy: 0.9833 - loss: 0.0265 - val_accuracy: 0.9843 - val_loss: 0.0252
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 840us/step - accuracy: 0.9844 - loss: 0.0244 - val_accuracy: 0.9845 - val_loss: 0.0244
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 852us/step - accuracy: 0.9843 - loss: 0.0239 - val_accuracy: 0.9846 - val_loss: 0.0244
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 844us/step - accuracy: 0.9842 - loss: 0.0240 - val_accuracy: 0.9847 - val_loss: 0.0237
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 842us/step - accuracy: 0.9846 - loss: 0.0238 - val_accuracy: 0.9846 - val_loss: 0.0237
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 858us/step - accuracy: 0.9845 - loss: 0.0235 - val_accuracy: 0.9847 - val_loss: 0.0238
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 861us/step - accuracy: 0.9845 - loss: 0.0238 - val_accuracy: 0.9846 - val_loss: 0.0242
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 477us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 448us/step
# Fold accuracy: 0.984644030668127
# Fold precision: 0.999001996007984
# Fold recall: 0.7412069603850425
# Fold F1-score: 0.851009564293305
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     42949
#            1       1.00      0.74      0.85      2701
#
#     accuracy                           0.98     45650
#    macro avg       0.99      0.87      0.92     45650
# weighted avg       0.98      0.98      0.98     45650
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 861us/step - accuracy: 0.9781 - loss: 0.0736 - val_accuracy: 0.9839 - val_loss: 0.0252
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 832us/step - accuracy: 0.9834 - loss: 0.0262 - val_accuracy: 0.9851 - val_loss: 0.0232
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 831us/step - accuracy: 0.9836 - loss: 0.0253 - val_accuracy: 0.9851 - val_loss: 0.0238
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 839us/step - accuracy: 0.9835 - loss: 0.0253 - val_accuracy: 0.9842 - val_loss: 0.0234
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 832us/step - accuracy: 0.9842 - loss: 0.0242 - val_accuracy: 0.9852 - val_loss: 0.0247
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 451us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 445us/step
# Fold accuracy: 0.9851478641840088
# Fold precision: 0.996969696969697
# Fold recall: 0.746031746031746
# Fold F1-score: 0.8534370946822308
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     43004
#            1       1.00      0.75      0.85      2646
#
#     accuracy                           0.99     45650
#    macro avg       0.99      0.87      0.92     45650
# weighted avg       0.99      0.99      0.98     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9845872808564756
# Mean precision: 0.9981665893663481
# Mean recall: 0.7378938913708633
# Mean F1-score: 0.848491059854491
#
# El tiempo de ejecucion fue: 381.983286857605

# %% [markdown]
# ---
#
# ### With DBN

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the DBN class
class DBN(BaseEstimator, TransformerMixin):
    def __init__(self, rbm_layers, rbm_learning_rate, rbm_n_iter):
        self.rbm_layers = rbm_layers
        self.rbm_learning_rate = rbm_learning_rate
        self.rbm_n_iter = rbm_n_iter
        self.rbms = []
        for i, n_components in enumerate(rbm_layers):
            self.rbms.append(BernoulliRBM(n_components=n_components, learning_rate=rbm_learning_rate, n_iter=rbm_n_iter, verbose=1))

    def fit(self, X, y=None):
        input_data = X
        for rbm in self.rbms:
            rbm.fit(input_data)
            input_data = rbm.transform(input_data)
        return self

    def transform(self, X):
        input_data = X
        for rbm in self.rbms:
            input_data = rbm.transform(input_data)
        return input_data

# Cross-validation
def cross_validation_dbn(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Normalize data
        scaler = MinMaxScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        dbn = DBN(rbm_layers=[n_inputs*2, n_inputs], rbm_learning_rate=0.1, rbm_n_iter=10)
        
        # Fit the DBN model
        dbn.fit(X_train)
        
        # Encode the data
        X_train_encoded = dbn.transform(X_train)
        X_test_encoded = dbn.transform(X_test)
        
        # Train AdaBoost classifier
        ab_classifier_encoded = AdaBoostClassifier(n_estimators=100, algorithm='SAMME', random_state=42)
        ab_classifier_encoded.fit(X_train_encoded, y_train)
        
        # Make predictions
        y_pred_encoded = ab_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")
    
    
tiempo_inicial = time()
#
cross_validation_dbn(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.50, time = 2.57s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.39, time = 3.20s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.46, time = 3.17s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.74, time = 3.17s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.65, time = 3.20s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.73, time = 3.24s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.73, time = 3.23s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.51, time = 3.17s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.69, time = 3.15s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.75, time = 3.10s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.46, time = 2.36s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -3.70, time = 2.92s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -3.93, time = 2.83s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -3.96, time = 2.80s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -3.87, time = 2.83s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -3.92, time = 2.81s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -3.90, time = 2.85s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -3.90, time = 2.85s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -3.97, time = 2.82s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -3.91, time = 2.78s
# Fold accuracy: 0.9826728877790191
# Fold precision: 0.9786802030456853
# Fold recall: 0.7202091893911095
# Fold F1-score: 0.8297826554766516
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     42974
#            1       0.98      0.72      0.83      2677
#
#     accuracy                           0.98     45651
#    macro avg       0.98      0.86      0.91     45651
# weighted avg       0.98      0.98      0.98     45651
#
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.83, time = 2.44s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.44, time = 3.12s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.43, time = 3.12s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.08, time = 3.25s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -5.07, time = 3.13s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.80, time = 3.22s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.72, time = 3.20s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.87, time = 3.18s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.72, time = 3.24s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.73, time = 3.16s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.62, time = 2.32s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.71, time = 2.78s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.74, time = 2.74s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.79, time = 2.84s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -5.97, time = 2.76s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -6.08, time = 2.85s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -6.05, time = 2.79s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -5.92, time = 2.81s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -5.93, time = 2.76s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -6.16, time = 2.85s
# Fold accuracy: 0.9716545092111892
# Fold precision: 0.8628745556119858
# Fold recall: 0.6239441792141021
# Fold F1-score: 0.7242114236999148
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     42928
#            1       0.86      0.62      0.72      2723
#
#     accuracy                           0.97     45651
#    macro avg       0.92      0.81      0.85     45651
# weighted avg       0.97      0.97      0.97     45651
#
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.76, time = 2.46s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.66, time = 3.21s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.19, time = 3.24s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.10, time = 3.23s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -5.17, time = 3.21s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.97, time = 3.12s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.72, time = 3.18s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.75, time = 3.19s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.89, time = 3.10s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.70, time = 3.06s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.33, time = 2.41s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -3.80, time = 2.78s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.01, time = 2.78s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.01, time = 2.80s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.03, time = 2.75s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -3.90, time = 2.83s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -3.94, time = 2.82s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -3.94, time = 2.79s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -3.94, time = 2.87s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.04, time = 2.91s
# Fold accuracy: 0.9822785919256971
# Fold precision: 0.9595079446437724
# Fold recall: 0.7194465795541891
# Fold F1-score: 0.8223149571710959
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     43049
#            1       0.96      0.72      0.82      2602
#
#     accuracy                           0.98     45651
#    macro avg       0.97      0.86      0.91     45651
# weighted avg       0.98      0.98      0.98     45651
#
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.04, time = 2.48s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.68, time = 3.29s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.84, time = 3.18s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.03, time = 3.23s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.69, time = 3.20s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.64, time = 3.23s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.65, time = 3.32s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.57, time = 3.21s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.58, time = 3.15s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.53, time = 3.13s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.58, time = 2.42s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.69, time = 2.91s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.42, time = 2.78s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.52, time = 2.85s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.76, time = 2.86s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.84, time = 2.79s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.56, time = 2.86s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.67, time = 2.81s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.77, time = 2.78s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.70, time = 2.79s
# Fold accuracy: 0.9808762322015334
# Fold precision: 0.9978213507625272
# Fold recall: 0.6782673084042947
# Fold F1-score: 0.8075821027110426
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     42949
#            1       1.00      0.68      0.81      2701
#
#     accuracy                           0.98     45650
#    macro avg       0.99      0.84      0.90     45650
# weighted avg       0.98      0.98      0.98     45650
#
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.07, time = 2.51s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.91, time = 3.17s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.75, time = 3.21s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.59, time = 3.25s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.82, time = 3.24s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.42, time = 3.13s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.51, time = 3.21s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.52, time = 3.17s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.52, time = 3.19s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.60, time = 3.11s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -3.55, time = 2.43s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -3.47, time = 2.84s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -3.65, time = 2.80s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -3.61, time = 2.93s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -3.64, time = 2.80s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -3.73, time = 2.84s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -3.76, time = 2.78s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -3.86, time = 2.84s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -3.65, time = 2.82s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -3.92, time = 2.90s
# Fold accuracy: 0.9835049288061336
# Fold precision: 0.9942558746736292
# Fold recall: 0.7195767195767195
# Fold F1-score: 0.8349046261784696
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     43004
#            1       0.99      0.72      0.83      2646
#
#     accuracy                           0.98     45650
#    macro avg       0.99      0.86      0.91     45650
# weighted avg       0.98      0.98      0.98     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9801974299847146
# Mean precision: 0.95862798574752
# Mean recall: 0.6922887952280831
# Mean F1-score: 0.803759153047435
#
# El tiempo de ejecucion fue: 847.3253288269043

# %% [markdown]
# ---
#
# ### With Autoencoder

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the autoencoder model
def create_autoencoder(n_inputs):
    inputs = Input(shape=(n_inputs,))
    
    # Define Encoder
    e = Dense(n_inputs*2)(inputs)
    e = BatchNormalization()(e)
    e = LeakyReLU()(e)
    
    # Bottleneck
    n_bottleneck = round(float(n_inputs)/2.0)
    bottleneck = Dense(n_bottleneck)(e)
    
    # Define Decoder
    d = Dense(n_inputs*2)(bottleneck)
    d = BatchNormalization()(d)
    d = LeakyReLU()(d)
    
    # Output layer
    outputs = Dense(n_inputs, activation='linear')(d)
    
    # Define autoencoder model
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='mse')
    
    # Define encoder model
    encoder = Model(inputs=inputs, outputs=bottleneck)
    
    return model, encoder

# Cross-validation
def cross_validation_autoencoder(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        autoencoder, encoder = create_autoencoder(n_inputs)
        
        # Early Stopping
        early_stopping1 = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)
        early_stopping2 = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
        
        # Fit the autoencoder model
        autoencoder.fit(X_train, X_train, epochs=100, batch_size=32, verbose=1,
                        validation_data=(X_test, X_test),
                        callbacks=[early_stopping1, early_stopping2])
        
        # Encode the data
        X_train_encoded = encoder.predict(X_train)
        X_test_encoded = encoder.predict(X_test)
        
        # Train AdaBoost classifier
        ab_classifier_encoded = AdaBoostClassifier(n_estimators=100, algorithm='SAMME', random_state=42)
        ab_classifier_encoded.fit(X_train_encoded, y_train)
        
        # Make predictions
        y_pred_encoded = ab_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")


tiempo_inicial = time()
#
cross_validation_autoencoder(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 744us/step - loss: 0.3218 - val_loss: 0.1440
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 722us/step - loss: 0.1348 - val_loss: 0.1581
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 724us/step - loss: 0.1524 - val_loss: 0.0677
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 720us/step - loss: 0.0937 - val_loss: 0.0649
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 733us/step - loss: 0.1666 - val_loss: 0.0448
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 721us/step - loss: 0.1285 - val_loss: 0.0377
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 723us/step - loss: 0.0982 - val_loss: 0.1650
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 724us/step - loss: 0.0774 - val_loss: 0.0368
# Epoch 9/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 728us/step - loss: 0.0647 - val_loss: 0.0431
# Epoch 10/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 724us/step - loss: 0.0934 - val_loss: 0.0801
# Epoch 11/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 727us/step - loss: 0.1018 - val_loss: 0.0329
# Epoch 12/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 721us/step - loss: 0.0696 - val_loss: 0.0552
# Epoch 13/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 731us/step - loss: 0.0564 - val_loss: 0.0504
# Epoch 14/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 724us/step - loss: 0.0513 - val_loss: 0.0394
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 418us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 411us/step
# Fold accuracy: 0.9817090534708988
# Fold precision: 0.9791883454734651
# Fold recall: 0.7030257751214045
# Fold F1-score: 0.8184387910415307
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     42974
#            1       0.98      0.70      0.82      2677
#
#     accuracy                           0.98     45651
#    macro avg       0.98      0.85      0.90     45651
# weighted avg       0.98      0.98      0.98     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 772us/step - loss: 0.2812 - val_loss: 0.2214
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 730us/step - loss: 0.1863 - val_loss: 0.0826
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 730us/step - loss: 0.1540 - val_loss: 0.2643
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 730us/step - loss: 0.1440 - val_loss: 0.0566
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 726us/step - loss: 0.1144 - val_loss: 0.1818
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 728us/step - loss: 0.0567 - val_loss: 0.0737
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 729us/step - loss: 0.0798 - val_loss: 0.0436
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 733us/step - loss: 0.0981 - val_loss: 0.1303
# Epoch 9/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 728us/step - loss: 0.0576 - val_loss: 0.2352
# Epoch 10/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 728us/step - loss: 0.1454 - val_loss: 0.0520
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 419us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 412us/step
# Fold accuracy: 0.9809423670894395
# Fold precision: 0.971021860701576
# Fold recall: 0.7014322438486963
# Fold F1-score: 0.814498933901919
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     42928
#            1       0.97      0.70      0.81      2723
#
#     accuracy                           0.98     45651
#    macro avg       0.98      0.85      0.90     45651
# weighted avg       0.98      0.98      0.98     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 749us/step - loss: 0.2734 - val_loss: 1.0222
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 728us/step - loss: 0.1294 - val_loss: 0.9815
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 733us/step - loss: 0.1270 - val_loss: 1.5105
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 743us/step - loss: 0.0902 - val_loss: 2.0229
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 741us/step - loss: 0.0955 - val_loss: 2.0131
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 416us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 417us/step
# Fold accuracy: 0.9842062605419377
# Fold precision: 0.9800918836140888
# Fold recall: 0.7378939277478862
# Fold F1-score: 0.8419206314404736
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     43049
#            1       0.98      0.74      0.84      2602
#
#     accuracy                           0.98     45651
#    macro avg       0.98      0.87      0.92     45651
# weighted avg       0.98      0.98      0.98     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 752us/step - loss: 0.2908 - val_loss: 0.0713
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 732us/step - loss: 0.1358 - val_loss: 0.0724
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 734us/step - loss: 0.1523 - val_loss: 0.0538
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 732us/step - loss: 0.2132 - val_loss: 0.2587
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 732us/step - loss: 0.1508 - val_loss: 0.0563
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 730us/step - loss: 0.0791 - val_loss: 0.1307
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 417us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 412us/step
# Fold accuracy: 0.983526834611172
# Fold precision: 0.9855505729945192
# Fold recall: 0.7323213624583488
# Fold F1-score: 0.8402718776550552
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     42949
#            1       0.99      0.73      0.84      2701
#
#     accuracy                           0.98     45650
#    macro avg       0.98      0.87      0.92     45650
# weighted avg       0.98      0.98      0.98     45650
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 753us/step - loss: 0.3085 - val_loss: 0.6232
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 733us/step - loss: 0.1966 - val_loss: 0.3930
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 736us/step - loss: 0.1179 - val_loss: 0.0879
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 740us/step - loss: 0.1338 - val_loss: 0.1018
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 731us/step - loss: 0.1256 - val_loss: 0.1288
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 734us/step - loss: 0.1021 - val_loss: 0.1321
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 417us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 413us/step
# Fold accuracy: 0.9833734939759036
# Fold precision: 0.9748364368394564
# Fold recall: 0.7320483749055178
# Fold F1-score: 0.8361752644075113
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     43004
#            1       0.97      0.73      0.84      2646
#
#     accuracy                           0.98     45650
#    macro avg       0.98      0.87      0.91     45650
# weighted avg       0.98      0.98      0.98     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9827516019378703
# Mean precision: 0.9781378199246212
# Mean recall: 0.7213443368163708
# Mean F1-score: 0.8302610996892981
#
# El tiempo de ejecucion fue: 452.32280921936035
