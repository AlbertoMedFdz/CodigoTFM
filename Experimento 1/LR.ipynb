# %% [markdown]
# _Alberto Medrano Fernández_
#
# # Logistic Regression

# %% [markdown]
# ---
#
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from time import time

from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler, LabelEncoder 
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.neural_network import BernoulliRBM
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

from tensorflow.keras.models import load_model, Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Input, Dense, BatchNormalization, ReLU, LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ---
#
# ## Dataset

# %%
hikari_2022 = pd.read_csv('ALLFLOWMETER_HIKARI2022.csv', sep=',')
hikari_2022
# Out:
#         Unnamed: 0                 uid       originh  originp  \
# 0                0  Cmu9v81jToQyRF1gbk  184.0.48.168    38164
# 1                1  CO21hl3TWkuXTOgajk  184.0.48.169    43068
# 2                2  CBLJ6L19FP0MfYX7Oh  184.0.48.124     5678
# 3                3  ChTG451zJ7hUYOcqje  184.0.48.124     5678
# 4                4  Cn9y6E2KVxzQbs5wjc  184.0.48.124     5678
# ...            ...                 ...           ...      ...
# 228248       16634   Clt16PPxzrXEtpa5d   184.0.48.20    53866
# 228249       53170  Cs8RA72uHDiQa5ch2k   184.0.48.20    54318
# 228250       53529  Cy4dqo4YEq5YGxjUXa   184.0.48.20    65355
# 228251       86308  CFXfNV3OTG04e0UnP4   184.0.48.20    53642
# 228252       99240  CqO7kc2eC5InNvWrtl   184.0.48.20    61000
#
#                 responh  responp           flow_duration  fwd_pkts_tot  \
# 0          184.0.48.150    50443  0 days 00:00:00.000060             1
# 1          184.0.48.150    50443  0 days 00:00:00.000083             1
# 2       255.255.255.255     5678  0 days 00:01:59.996602             3
# 3       255.255.255.255     5678  0 days 00:00:59.996909             2
# 4       255.255.255.255     5678  0 days 00:00:59.992130             2
# ...                 ...      ...                     ...           ...
# 228248     184.0.48.255     1947  0 days 00:00:00.000027             2
# 228249     184.0.48.255     1947  0 days 00:00:00.000027             2
# 228250     184.0.48.255     1947         0 days 00:00:00             2
# 228251     184.0.48.255     1947  0 days 00:00:00.000054             2
# 228252     184.0.48.255     1947         0 days 00:00:00             2
#
#         bwd_pkts_tot  fwd_data_pkts_tot  ...      idle.max      idle.tot  \
# 0                  1                  0  ...  0.000000e+00  0.000000e+00
# 1                  1                  0  ...  0.000000e+00  0.000000e+00
# 2                  0                  3  ...  5.999912e+07  1.199966e+08
# 3                  0                  2  ...  5.999691e+07  5.999691e+07
# 4                  0                  2  ...  5.999213e+07  5.999213e+07
# ...              ...                ...  ...           ...           ...
# 228248             0                  2  ...  0.000000e+00  0.000000e+00
# 228249             0                  2  ...  0.000000e+00  0.000000e+00
# 228250             0                  2  ...  0.000000e+00  0.000000e+00
# 228251             0                  2  ...  0.000000e+00  0.000000e+00
# 228252             0                  2  ...  0.000000e+00  0.000000e+00
#
#             idle.avg     idle.std  fwd_init_window_size  bwd_init_window_size  \
# 0       0.000000e+00     0.000000                 64240                     0
# 1       0.000000e+00     0.000000                 64240                     0
# 2       5.999830e+07  1156.846698                     0                     0
# 3       5.999691e+07     0.000000                     0                     0
# 4       5.999213e+07     0.000000                     0                     0
# ...              ...          ...                   ...                   ...
# 228248  0.000000e+00     0.000000                     0                     0
# 228249  0.000000e+00     0.000000                     0                     0
# 228250  0.000000e+00     0.000000                     0                     0
# 228251  0.000000e+00     0.000000                     0                     0
# 228252  0.000000e+00     0.000000                     0                     0
#
#         fwd_last_window_size  bwd_last_window_size      attack_category  Label
# 0                      64240                     0               Benign      0
# 1                      64240                     0               Benign      0
# 2                          0                     0               Benign      0
# 3                          0                     0               Benign      0
# 4                          0                     0               Benign      0
# ...                      ...                   ...                  ...    ...
# 228248                     0                     0  XMRIGCC CryptoMiner      1
# 228249                     0                     0  XMRIGCC CryptoMiner      1
# 228250                     0                     0  XMRIGCC CryptoMiner      1
# 228251                     0                     0  XMRIGCC CryptoMiner      1
# 228252                     0                     0  XMRIGCC CryptoMiner      1
#
# [228253 rows x 88 columns]

# %%
hikari_2022 = hikari_2022.drop(columns=['Unnamed: 0', 'uid', 'originh', 'responh', 'flow_duration', 'fwd_URG_flag_count', 
                                        'bwd_URG_flag_count', 'attack_category'])
hikari_2022
# Out:
#         originp  responp  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  \
# 0         38164    50443             1             1                  0
# 1         43068    50443             1             1                  0
# 2          5678     5678             3             0                  3
# 3          5678     5678             2             0                  2
# 4          5678     5678             2             0                  2
# ...         ...      ...           ...           ...                ...
# 228248    53866     1947             2             0                  2
# 228249    54318     1947             2             0                  2
# 228250    65355     1947             2             0                  2
# 228251    53642     1947             2             0                  2
# 228252    61000     1947             2             0                  2
#
#         bwd_data_pkts_tot  fwd_pkts_per_sec  bwd_pkts_per_sec  \
# 0                       0      16644.063492      16644.063492
# 1                       0      12052.597701      12052.597701
# 2                       0          0.025001          0.000000
# 3                       0          0.033335          0.000000
# 4                       0          0.033338          0.000000
# ...                   ...               ...               ...
# 228248                  0      73584.280702          0.000000
# 228249                  0      74235.469027          0.000000
# 228250                  0          0.000000          0.000000
# 228251                  0      37117.734513          0.000000
# 228252                  0          0.000000          0.000000
#
#         flow_pkts_per_sec  down_up_ratio  ...      idle.min      idle.max  \
# 0            33288.126984            1.0  ...  0.000000e+00  0.000000e+00
# 1            24105.195402            1.0  ...  0.000000e+00  0.000000e+00
# 2                0.025001            0.0  ...  5.999748e+07  5.999912e+07
# 3                0.033335            0.0  ...  5.999691e+07  5.999691e+07
# 4                0.033338            0.0  ...  5.999213e+07  5.999213e+07
# ...                   ...            ...  ...           ...           ...
# 228248       73584.280702            0.0  ...  0.000000e+00  0.000000e+00
# 228249       74235.469027            0.0  ...  0.000000e+00  0.000000e+00
# 228250           0.000000            0.0  ...  0.000000e+00  0.000000e+00
# 228251       37117.734513            0.0  ...  0.000000e+00  0.000000e+00
# 228252           0.000000            0.0  ...  0.000000e+00  0.000000e+00
#
#             idle.tot      idle.avg     idle.std  fwd_init_window_size  \
# 0       0.000000e+00  0.000000e+00     0.000000                 64240
# 1       0.000000e+00  0.000000e+00     0.000000                 64240
# 2       1.199966e+08  5.999830e+07  1156.846698                     0
# 3       5.999691e+07  5.999691e+07     0.000000                     0
# 4       5.999213e+07  5.999213e+07     0.000000                     0
# ...              ...           ...          ...                   ...
# 228248  0.000000e+00  0.000000e+00     0.000000                     0
# 228249  0.000000e+00  0.000000e+00     0.000000                     0
# 228250  0.000000e+00  0.000000e+00     0.000000                     0
# 228251  0.000000e+00  0.000000e+00     0.000000                     0
# 228252  0.000000e+00  0.000000e+00     0.000000                     0
#
#         bwd_init_window_size  fwd_last_window_size  bwd_last_window_size  \
# 0                          0                 64240                     0
# 1                          0                 64240                     0
# 2                          0                     0                     0
# 3                          0                     0                     0
# 4                          0                     0                     0
# ...                      ...                   ...                   ...
# 228248                     0                     0                     0
# 228249                     0                     0                     0
# 228250                     0                     0                     0
# 228251                     0                     0                     0
# 228252                     0                     0                     0
#
#         Label
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 228248      1
# 228249      1
# 228250      1
# 228251      1
# 228252      1
#
# [228253 rows x 80 columns]

# %%
# Calculate Pearson correlation coefficient
corr = hikari_2022.corr(method ='pearson')

# Extract the correlation with the target variable 'Label'
corr_with_target = corr['Label']

# Select only columns with a correlation less than 0.05
relevant_features = corr_with_target[abs(corr_with_target) >= 0.05].index

# Filter the DataFrame to keep only the relevant features
hikari_2022 = hikari_2022[relevant_features]

print("Dataset after EDA:")
hikari_2022
# Out:
# Dataset after EDA:
#         originp  responp  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  \
# 0         38164    50443             1             1                  0
# 1         43068    50443             1             1                  0
# 2          5678     5678             3             0                  3
# 3          5678     5678             2             0                  2
# 4          5678     5678             2             0                  2
# ...         ...      ...           ...           ...                ...
# 228248    53866     1947             2             0                  2
# 228249    54318     1947             2             0                  2
# 228250    65355     1947             2             0                  2
# 228251    53642     1947             2             0                  2
# 228252    61000     1947             2             0                  2
#
#         bwd_data_pkts_tot  bwd_pkts_per_sec  down_up_ratio  \
# 0                       0      16644.063492            1.0
# 1                       0      12052.597701            1.0
# 2                       0          0.000000            0.0
# 3                       0          0.000000            0.0
# 4                       0          0.000000            0.0
# ...                   ...               ...            ...
# 228248                  0          0.000000            0.0
# 228249                  0          0.000000            0.0
# 228250                  0          0.000000            0.0
# 228251                  0          0.000000            0.0
# 228252                  0          0.000000            0.0
#
#         fwd_header_size_tot  fwd_header_size_min  ...  bwd_subflow_bytes  \
# 0                        40                   40  ...                0.0
# 1                        40                   40  ...                0.0
# 2                        24                    8  ...                0.0
# 3                        16                    8  ...                0.0
# 4                        16                    8  ...                0.0
# ...                     ...                  ...  ...                ...
# 228248                   16                    8  ...                0.0
# 228249                   16                    8  ...                0.0
# 228250                   16                    8  ...                0.0
# 228251                   16                    8  ...                0.0
# 228252                   16                    8  ...                0.0
#
#         fwd_bulk_packets  bwd_bulk_packets  active.min  active.max  \
# 0                    0.0               0.0   60.081482   60.081482
# 1                    0.0               0.0   82.969666   82.969666
# 2                    0.0               0.0    0.000000    0.000000
# 3                    0.0               0.0    0.000000    0.000000
# 4                    0.0               0.0    0.000000    0.000000
# ...                  ...               ...         ...         ...
# 228248               0.0               0.0   27.179718   27.179718
# 228249               0.0               0.0   26.941299   26.941299
# 228250               0.0               0.0    0.000000    0.000000
# 228251               0.0               0.0   53.882599   53.882599
# 228252               0.0               0.0    0.000000    0.000000
#
#         active.avg  fwd_init_window_size  bwd_init_window_size  \
# 0        60.081482                 64240                     0
# 1        82.969666                 64240                     0
# 2         0.000000                     0                     0
# 3         0.000000                     0                     0
# 4         0.000000                     0                     0
# ...            ...                   ...                   ...
# 228248   27.179718                     0                     0
# 228249   26.941299                     0                     0
# 228250    0.000000                     0                     0
# 228251   53.882599                     0                     0
# 228252    0.000000                     0                     0
#
#         fwd_last_window_size  Label
# 0                      64240      0
# 1                      64240      0
# 2                          0      0
# 3                          0      0
# 4                          0      0
# ...                      ...    ...
# 228248                     0      1
# 228249                     0      1
# 228250                     0      1
# 228251                     0      1
# 228252                     0      1
#
# [228253 rows x 44 columns]

# %% [markdown]
# ---
#
# ## Models

# %% [markdown]
# ### Without feature extraction

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Cross-validation
def cross_validation(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []

    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        # Train Logistic Regression classifier
        lr_classifier = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)
        lr_classifier.fit(X_train, y_train)

        # Make predictions
        y_pred = lr_classifier.predict(X_test)

        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")   



tiempo_inicial = time()
#
cross_validation(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# Fold accuracy: 0.9723554796170949
# Fold precision: 0.6797966963151207
# Fold recall: 0.999252895031752
# Fold F1-score: 0.809134906231095
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     42974
#            1       0.68      1.00      0.81      2677
#
#     accuracy                           0.97     45651
#    macro avg       0.84      0.98      0.90     45651
# weighted avg       0.98      0.97      0.97     45651
#
# Fold accuracy: 0.9726621541696786
# Fold precision: 0.6863785696234521
# Fold recall: 0.9974293059125964
# Fold F1-score: 0.8131736526946107
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     42928
#            1       0.69      1.00      0.81      2723
#
#     accuracy                           0.97     45651
#    macro avg       0.84      0.98      0.90     45651
# weighted avg       0.98      0.97      0.97     45651
#
# Fold accuracy: 0.9731878819741079
# Fold precision: 0.6805555555555556
# Fold recall: 0.9980784012298232
# Fold F1-score: 0.809286382050483
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     43049
#            1       0.68      1.00      0.81      2602
#
#     accuracy                           0.97     45651
#    macro avg       0.84      0.98      0.90     45651
# weighted avg       0.98      0.97      0.98     45651
#
# Fold accuracy: 0.971434830230011
# Fold precision: 0.6744941294029478
# Fold recall: 0.9996297667530544
# Fold F1-score: 0.8054892601431981
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     42949
#            1       0.67      1.00      0.81      2701
#
#     accuracy                           0.97     45650
#    macro avg       0.84      0.98      0.90     45650
# weighted avg       0.98      0.97      0.97     45650
#
# Fold accuracy: 0.9719167579408543
# Fold precision: 0.673713703515028
# Fold recall: 0.9996220710506425
# Fold F1-score: 0.8049300060864273
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     43004
#            1       0.67      1.00      0.80      2646
#
#     accuracy                           0.97     45650
#    macro avg       0.84      0.98      0.89     45650
# weighted avg       0.98      0.97      0.97     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9723114207863492
# Mean precision: 0.6789877308824208
# Mean recall: 0.9988024879955736
# Mean F1-score: 0.8084028414411628
#
# El tiempo de ejecucion fue: 16.37376093864441

# %% [markdown]
# ---
#
# ### With DNN

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the DNN model
def create_dnn(input_dim):
    inputs = Input(shape=(input_dim,))
    
    # Hidden layer 1
    x = Dense(input_dim * 2)(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    # Hidden layer 2
    x = Dense(input_dim)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    # Feature layer
    n_bottleneck = round(float(input_dim) / 2.0)
    bottleneck = Dense(n_bottleneck)(x)
    bottleneck = BatchNormalization()(bottleneck)
    bottleneck = ReLU()(bottleneck)
    
    # Output layer
    outputs = Dense(1, activation='sigmoid')(bottleneck)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    # Model for feature extraction
    feature_extractor = Model(inputs=inputs, outputs=bottleneck)
    
    return model, feature_extractor

# Cross-validation
def cross_validation_dnn(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        dnn, feature_extractor = create_dnn(n_inputs)
        
        # Early Stopping
        early_stopping1 = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)
        early_stopping2 = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
        
        # Fit the DNN model
        dnn.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1,
                        validation_data=(X_test, y_test),
                        callbacks=[early_stopping1, early_stopping2])
        
        # Encode the data
        X_train_encoded = feature_extractor.predict(X_train)
        X_test_encoded = feature_extractor.predict(X_test)
        
        # Train Logistic Regression classifier
        lr_classifier_encoded = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)
        lr_classifier_encoded.fit(X_train_encoded, y_train)
        
        # Make predictions
        y_pred_encoded = lr_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")


tiempo_inicial = time()
#
cross_validation_dnn(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 879us/step - accuracy: 0.9626 - loss: 0.1040 - val_accuracy: 0.9842 - val_loss: 0.0254
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 839us/step - accuracy: 0.9832 - loss: 0.0269 - val_accuracy: 0.9840 - val_loss: 0.0254
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 824us/step - accuracy: 0.9835 - loss: 0.0261 - val_accuracy: 0.9844 - val_loss: 0.0244
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 836us/step - accuracy: 0.9847 - loss: 0.0245 - val_accuracy: 0.9842 - val_loss: 0.0250
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 843us/step - accuracy: 0.9840 - loss: 0.0245 - val_accuracy: 0.9841 - val_loss: 0.0247
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 829us/step - accuracy: 0.9842 - loss: 0.0241 - val_accuracy: 0.9843 - val_loss: 0.0241
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 833us/step - accuracy: 0.9846 - loss: 0.0235 - val_accuracy: 0.9842 - val_loss: 0.0250
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 828us/step - accuracy: 0.9853 - loss: 0.0234 - val_accuracy: 0.9829 - val_loss: 0.0252
# Epoch 9/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 843us/step - accuracy: 0.9846 - loss: 0.0234 - val_accuracy: 0.9844 - val_loss: 0.0236
# Epoch 10/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 836us/step - accuracy: 0.9843 - loss: 0.0239 - val_accuracy: 0.9844 - val_loss: 0.0236
# Epoch 11/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 835us/step - accuracy: 0.9850 - loss: 0.0228 - val_accuracy: 0.9844 - val_loss: 0.0236
# Epoch 12/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 848us/step - accuracy: 0.9847 - loss: 0.0240 - val_accuracy: 0.9844 - val_loss: 0.0238
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 461us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 450us/step
# Fold accuracy: 0.9819062013975598
# Fold precision: 0.7648068669527897
# Fold recall: 0.9985057900635039
# Fold F1-score: 0.8661697990926766
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     42974
#            1       0.76      1.00      0.87      2677
#
#     accuracy                           0.98     45651
#    macro avg       0.88      0.99      0.93     45651
# weighted avg       0.99      0.98      0.98     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 872us/step - accuracy: 0.9792 - loss: 0.0629 - val_accuracy: 0.9832 - val_loss: 0.0279
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 837us/step - accuracy: 0.9842 - loss: 0.0257 - val_accuracy: 0.9828 - val_loss: 0.0272
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 846us/step - accuracy: 0.9841 - loss: 0.0251 - val_accuracy: 0.9835 - val_loss: 0.0255
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 841us/step - accuracy: 0.9841 - loss: 0.0242 - val_accuracy: 0.9835 - val_loss: 0.0259
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 829us/step - accuracy: 0.9846 - loss: 0.0237 - val_accuracy: 0.9837 - val_loss: 0.0262
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 818us/step - accuracy: 0.9846 - loss: 0.0244 - val_accuracy: 0.9824 - val_loss: 0.0286
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 461us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 453us/step
# Fold accuracy: 0.9812928522923923
# Fold precision: 0.762278978388998
# Fold recall: 0.9974293059125964
# Fold F1-score: 0.8641425389755011
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     42928
#            1       0.76      1.00      0.86      2723
#
#     accuracy                           0.98     45651
#    macro avg       0.88      0.99      0.93     45651
# weighted avg       0.99      0.98      0.98     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 866us/step - accuracy: 0.9786 - loss: 0.0638 - val_accuracy: 0.9835 - val_loss: 0.0257
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 841us/step - accuracy: 0.9839 - loss: 0.0261 - val_accuracy: 0.9837 - val_loss: 0.0262
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 854us/step - accuracy: 0.9836 - loss: 0.0250 - val_accuracy: 0.9854 - val_loss: 0.0224
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 841us/step - accuracy: 0.9840 - loss: 0.0255 - val_accuracy: 0.9853 - val_loss: 0.0259
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 821us/step - accuracy: 0.9844 - loss: 0.0242 - val_accuracy: 0.9854 - val_loss: 0.0224
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 826us/step - accuracy: 0.9840 - loss: 0.0244 - val_accuracy: 0.9844 - val_loss: 0.0229
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 860us/step - accuracy: 0.9843 - loss: 0.0239 - val_accuracy: 0.9853 - val_loss: 0.0227
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 845us/step - accuracy: 0.9843 - loss: 0.0238 - val_accuracy: 0.9852 - val_loss: 0.0245
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 460us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 464us/step
# Fold accuracy: 0.9828481303804955
# Fold precision: 0.7691624741047647
# Fold recall: 0.9988470407378939
# Fold F1-score: 0.8690854372178566
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     43049
#            1       0.77      1.00      0.87      2602
#
#     accuracy                           0.98     45651
#    macro avg       0.88      0.99      0.93     45651
# weighted avg       0.99      0.98      0.98     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 861us/step - accuracy: 0.9723 - loss: 0.0790 - val_accuracy: 0.9843 - val_loss: 0.0250
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 827us/step - accuracy: 0.9836 - loss: 0.0268 - val_accuracy: 0.9837 - val_loss: 0.0251
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 829us/step - accuracy: 0.9841 - loss: 0.0252 - val_accuracy: 0.9845 - val_loss: 0.0237
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 833us/step - accuracy: 0.9841 - loss: 0.0248 - val_accuracy: 0.9846 - val_loss: 0.0246
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 841us/step - accuracy: 0.9839 - loss: 0.0247 - val_accuracy: 0.9845 - val_loss: 0.0246
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 837us/step - accuracy: 0.9846 - loss: 0.0241 - val_accuracy: 0.9833 - val_loss: 0.0299
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 453us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 444us/step
# Fold accuracy: 0.9814895947426068
# Fold precision: 0.7617033276931754
# Fold recall: 1.0
# Fold F1-score: 0.8647350728349608
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     42949
#            1       0.76      1.00      0.86      2701
#
#     accuracy                           0.98     45650
#    macro avg       0.88      0.99      0.93     45650
# weighted avg       0.99      0.98      0.98     45650
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 854us/step - accuracy: 0.9540 - loss: 0.1116 - val_accuracy: 0.9843 - val_loss: 0.0250
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 852us/step - accuracy: 0.9835 - loss: 0.0263 - val_accuracy: 0.9852 - val_loss: 0.0232
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 858us/step - accuracy: 0.9835 - loss: 0.0255 - val_accuracy: 0.9851 - val_loss: 0.0240
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 852us/step - accuracy: 0.9844 - loss: 0.0246 - val_accuracy: 0.9853 - val_loss: 0.0231
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 845us/step - accuracy: 0.9836 - loss: 0.0254 - val_accuracy: 0.9851 - val_loss: 0.0227
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 851us/step - accuracy: 0.9844 - loss: 0.0243 - val_accuracy: 0.9843 - val_loss: 0.0241
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 832us/step - accuracy: 0.9842 - loss: 0.0242 - val_accuracy: 0.9851 - val_loss: 0.0230
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 840us/step - accuracy: 0.9839 - loss: 0.0237 - val_accuracy: 0.9853 - val_loss: 0.0218
# Epoch 9/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 842us/step - accuracy: 0.9846 - loss: 0.0237 - val_accuracy: 0.9851 - val_loss: 0.0231
# Epoch 10/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 854us/step - accuracy: 0.9845 - loss: 0.0238 - val_accuracy: 0.9853 - val_loss: 0.0225
# Epoch 11/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 842us/step - accuracy: 0.9839 - loss: 0.0239 - val_accuracy: 0.9851 - val_loss: 0.0224
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 457us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 456us/step
# Fold accuracy: 0.9830010952902519
# Fold precision: 0.7732320280537697
# Fold recall: 1.0
# Fold F1-score: 0.8721160184574819
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     43004
#            1       0.77      1.00      0.87      2646
#
#     accuracy                           0.98     45650
#    macro avg       0.89      0.99      0.93     45650
# weighted avg       0.99      0.98      0.98     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9821075748206611
# Mean precision: 0.7662367350386995
# Mean recall: 0.9989564273427988
# Mean F1-score: 0.8672497733156954
#
# El tiempo de ejecucion fue: 242.2144181728363

# %% [markdown]
# ---
#
# ### With DBN

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the DBN class
class DBN(BaseEstimator, TransformerMixin):
    def __init__(self, rbm_layers, rbm_learning_rate, rbm_n_iter):
        self.rbm_layers = rbm_layers
        self.rbm_learning_rate = rbm_learning_rate
        self.rbm_n_iter = rbm_n_iter
        self.rbms = []
        for i, n_components in enumerate(rbm_layers):
            self.rbms.append(BernoulliRBM(n_components=n_components, learning_rate=rbm_learning_rate, n_iter=rbm_n_iter, verbose=1))

    def fit(self, X, y=None):
        input_data = X
        for rbm in self.rbms:
            rbm.fit(input_data)
            input_data = rbm.transform(input_data)
        return self

    def transform(self, X):
        input_data = X
        for rbm in self.rbms:
            input_data = rbm.transform(input_data)
        return input_data

# Cross-validation
def cross_validation_dbn(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Normalize data
        scaler = MinMaxScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        dbn = DBN(rbm_layers=[n_inputs*2, n_inputs], rbm_learning_rate=0.1, rbm_n_iter=10)
        
        # Fit the DBN model
        dbn.fit(X_train)
        
        # Encode the data
        X_train_encoded = dbn.transform(X_train)
        X_test_encoded = dbn.transform(X_test)
        
        # Train Logistic Regression classifier
        lr_classifier_encoded = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)
        lr_classifier_encoded.fit(X_train_encoded, y_train)
        
        # Make predictions
        y_pred_encoded = lr_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")
    
    
tiempo_inicial = time()
#
cross_validation_dbn(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.63, time = 2.68s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.39, time = 3.24s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.02, time = 3.34s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.75, time = 3.30s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.77, time = 3.20s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.71, time = 3.51s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.93, time = 3.30s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.66, time = 3.18s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.65, time = 3.16s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.70, time = 3.16s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.04, time = 2.56s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.73, time = 2.93s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.81, time = 2.85s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.87, time = 2.88s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.72, time = 2.87s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.86, time = 3.04s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.99, time = 2.91s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.89, time = 2.90s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.93, time = 2.90s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.81, time = 2.91s
# Fold accuracy: 0.7284615890122889
# Fold precision: 0.12191706216447522
# Fold recall: 0.5853567426223384
# Fold F1-score: 0.20180296200901482
#               precision    recall  f1-score   support
#
#            0       0.97      0.74      0.84     42974
#            1       0.12      0.59      0.20      2677
#
#     accuracy                           0.73     45651
#    macro avg       0.54      0.66      0.52     45651
# weighted avg       0.92      0.73      0.80     45651
#
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -6.32, time = 2.67s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.07, time = 3.36s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.02, time = 3.34s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.32, time = 3.49s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -5.12, time = 3.25s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.89, time = 3.41s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.76, time = 3.21s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.79, time = 3.28s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.64, time = 3.27s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.75, time = 3.32s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.83, time = 2.58s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.28, time = 2.97s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.31, time = 2.86s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.49, time = 2.86s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.39, time = 2.90s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.41, time = 2.97s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.37, time = 2.92s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.48, time = 3.01s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.43, time = 2.86s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.47, time = 2.81s
# Fold accuracy: 0.7233795535694727
# Fold precision: 0.12116576149315383
# Fold recall: 0.5817113477781858
# Fold F1-score: 0.20055710306406685
#               precision    recall  f1-score   support
#
#            0       0.97      0.73      0.83     42928
#            1       0.12      0.58      0.20      2723
#
#     accuracy                           0.72     45651
#    macro avg       0.54      0.66      0.52     45651
# weighted avg       0.91      0.72      0.80     45651
#
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -6.22, time = 2.50s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -6.36, time = 3.30s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.51, time = 3.33s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.00, time = 3.42s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -5.20, time = 3.28s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.96, time = 3.33s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.81, time = 3.36s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.94, time = 3.28s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.78, time = 3.23s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.77, time = 3.30s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.13, time = 2.50s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -3.36, time = 3.00s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -3.48, time = 2.88s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -3.50, time = 3.01s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -3.58, time = 2.95s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -3.58, time = 2.89s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -3.52, time = 3.07s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -3.40, time = 2.96s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -3.46, time = 2.86s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -3.49, time = 2.90s
# Fold accuracy: 0.9076690543471118
# Fold precision: 0.32025852462669935
# Fold recall: 0.5522674865488086
# Fold F1-score: 0.4054168429961913
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     43049
#            1       0.32      0.55      0.41      2602
#
#     accuracy                           0.91     45651
#    macro avg       0.65      0.74      0.68     45651
# weighted avg       0.93      0.91      0.92     45651
#
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.48, time = 2.53s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.03, time = 3.35s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.45, time = 3.23s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.79, time = 3.22s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.67, time = 3.23s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.69, time = 3.29s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.67, time = 3.18s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.64, time = 3.27s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.98, time = 3.21s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.68, time = 3.15s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -3.83, time = 2.47s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.48, time = 2.92s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.28, time = 2.88s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.44, time = 2.90s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.05, time = 2.99s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -3.64, time = 2.88s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.29, time = 2.95s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -3.74, time = 2.88s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -3.80, time = 2.92s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -3.66, time = 2.88s
# Fold accuracy: 0.904249726177437
# Fold precision: 0.3223404255319149
# Fold recall: 0.5609033691225472
# Fold F1-score: 0.4094041345764086
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     42949
#            1       0.32      0.56      0.41      2701
#
#     accuracy                           0.90     45650
#    macro avg       0.65      0.74      0.68     45650
# weighted avg       0.93      0.90      0.92     45650
#
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.21, time = 2.46s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.43, time = 3.31s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.61, time = 3.26s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.62, time = 3.35s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.72, time = 3.46s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.65, time = 3.32s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.60, time = 3.42s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.44, time = 3.26s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.58, time = 3.33s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.58, time = 3.17s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.02, time = 2.41s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.64, time = 2.99s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.93, time = 2.90s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.99, time = 2.85s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.97, time = 2.90s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -5.00, time = 2.93s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.91, time = 2.94s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.75, time = 2.86s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.77, time = 2.87s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -5.05, time = 2.86s
# Fold accuracy: 0.9070317634173056
# Fold precision: 0.32577409507195815
# Fold recall: 0.564625850340136
# Fold F1-score: 0.4131637168141593
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     43004
#            1       0.33      0.56      0.41      2646
#
#     accuracy                           0.91     45650
#    macro avg       0.65      0.75      0.68     45650
# weighted avg       0.93      0.91      0.92     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.8341583373047232
# Mean precision: 0.24229117377764026
# Mean recall: 0.5689729592824032
# Mean F1-score: 0.32606895189196816
#
# El tiempo de ejecucion fue: 315.9256844520569

# %% [markdown]
# ---
#
# ### With Autoencoder

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the autoencoder model
def create_autoencoder(n_inputs):
    inputs = Input(shape=(n_inputs,))
    
    # Define Encoder
    e = Dense(n_inputs*2)(inputs)
    e = BatchNormalization()(e)
    e = LeakyReLU()(e)
    
    # Bottleneck
    n_bottleneck = round(float(n_inputs)/2.0)
    bottleneck = Dense(n_bottleneck)(e)
    
    # Define Decoder
    d = Dense(n_inputs*2)(bottleneck)
    d = BatchNormalization()(d)
    d = LeakyReLU()(d)
    
    # Output layer
    outputs = Dense(n_inputs, activation='linear')(d)
    
    # Define autoencoder model
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='mse')
    
    # Define encoder model
    encoder = Model(inputs=inputs, outputs=bottleneck)
    
    return model, encoder

# Cross-validation
def cross_validation_autoencoder(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        autoencoder, encoder = create_autoencoder(n_inputs)
        
        # Early Stopping
        early_stopping1 = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)
        early_stopping2 = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
        
        # Fit the autoencoder model
        autoencoder.fit(X_train, X_train, epochs=100, batch_size=32, verbose=1,
                        validation_data=(X_test, X_test),
                        callbacks=[early_stopping1, early_stopping2])
        
        # Encode the data
        X_train_encoded = encoder.predict(X_train)
        X_test_encoded = encoder.predict(X_test)
        
        ## Train Logistic Regression classifier
        lr_classifier_encoded = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)
        lr_classifier_encoded.fit(X_train_encoded, y_train)
        
        # Make predictions
        y_pred_encoded = lr_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")


tiempo_inicial = time()
#
cross_validation_autoencoder(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 745us/step - loss: 0.4312 - val_loss: 0.1261
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 732us/step - loss: 0.1046 - val_loss: 0.3056
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 729us/step - loss: 0.1336 - val_loss: 0.0816
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 724us/step - loss: 0.1131 - val_loss: 0.1497
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 728us/step - loss: 0.1229 - val_loss: 0.0382
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 723us/step - loss: 0.1173 - val_loss: 0.0521
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 727us/step - loss: 0.1024 - val_loss: 0.0500
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 727us/step - loss: 0.0777 - val_loss: 0.0496
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 409us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 405us/step
# Fold accuracy: 0.9681496571816609
# Fold precision: 0.648386314001456
# Fold recall: 0.9981322375793799
# Fold F1-score: 0.7861135628125919
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     42974
#            1       0.65      1.00      0.79      2677
#
#     accuracy                           0.97     45651
#    macro avg       0.82      0.98      0.88     45651
# weighted avg       0.98      0.97      0.97     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 760us/step - loss: 0.3503 - val_loss: 0.2679
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 729us/step - loss: 0.1198 - val_loss: 0.2904
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 732us/step - loss: 0.1230 - val_loss: 0.1194
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 728us/step - loss: 0.1168 - val_loss: 0.0648
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 729us/step - loss: 0.1272 - val_loss: 0.2075
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 728us/step - loss: 0.1026 - val_loss: 0.1141
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 740us/step - loss: 0.0792 - val_loss: 0.0920
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 409us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 424us/step
# Fold accuracy: 0.9708002015289917
# Fold precision: 0.6721149083704805
# Fold recall: 0.9966948218876239
# Fold F1-score: 0.8028398165951782
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     42928
#            1       0.67      1.00      0.80      2723
#
#     accuracy                           0.97     45651
#    macro avg       0.84      0.98      0.89     45651
# weighted avg       0.98      0.97      0.97     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 749us/step - loss: 0.3038 - val_loss: 1.9235
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 735us/step - loss: 0.1480 - val_loss: 2.1669
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 728us/step - loss: 0.1158 - val_loss: 2.2755
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 729us/step - loss: 0.0976 - val_loss: 1.8208
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 736us/step - loss: 0.1286 - val_loss: 1.0857
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 726us/step - loss: 0.0796 - val_loss: 1.1453
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 734us/step - loss: 0.0657 - val_loss: 1.7241
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 729us/step - loss: 0.0641 - val_loss: 0.8898
# Epoch 9/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 764us/step - loss: 0.0502 - val_loss: 0.9180
# Epoch 10/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 754us/step - loss: 0.0753 - val_loss: 0.9108
# Epoch 11/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 752us/step - loss: 0.0608 - val_loss: 0.9497
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 414us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 404us/step
# Fold accuracy: 0.9711506867319445
# Fold precision: 0.6644484259022267
# Fold recall: 0.9976940814757879
# Fold F1-score: 0.7976647718543555
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     43049
#            1       0.66      1.00      0.80      2602
#
#     accuracy                           0.97     45651
#    macro avg       0.83      0.98      0.89     45651
# weighted avg       0.98      0.97      0.97     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 753us/step - loss: 0.3675 - val_loss: 0.6601
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 722us/step - loss: 0.1328 - val_loss: 0.0731
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 723us/step - loss: 0.1504 - val_loss: 0.4097
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 735us/step - loss: 0.1258 - val_loss: 0.0645
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 751us/step - loss: 0.1188 - val_loss: 0.0783
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 764us/step - loss: 0.0791 - val_loss: 0.1111
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 759us/step - loss: 0.0985 - val_loss: 0.0622
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 752us/step - loss: 0.0872 - val_loss: 0.0432
# Epoch 9/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 738us/step - loss: 0.0830 - val_loss: 0.2285
# Epoch 10/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 730us/step - loss: 0.0610 - val_loss: 0.0966
# Epoch 11/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 777us/step - loss: 0.0610 - val_loss: 0.1163
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 420us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 409us/step
# Fold accuracy: 0.9688718510405258
# Fold precision: 0.6554152501214182
# Fold recall: 0.9992595335061089
# Fold F1-score: 0.7916116732658748
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     42949
#            1       0.66      1.00      0.79      2701
#
#     accuracy                           0.97     45650
#    macro avg       0.83      0.98      0.89     45650
# weighted avg       0.98      0.97      0.97     45650
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 744us/step - loss: 0.2881 - val_loss: 0.2876
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 723us/step - loss: 0.1882 - val_loss: 0.2172
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 724us/step - loss: 0.1647 - val_loss: 0.1558
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 719us/step - loss: 0.0913 - val_loss: 0.0974
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 720us/step - loss: 0.1076 - val_loss: 0.3741
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 726us/step - loss: 0.0763 - val_loss: 0.1145
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 720us/step - loss: 0.0790 - val_loss: 0.0573
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 722us/step - loss: 0.0616 - val_loss: 0.4216
# Epoch 9/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 720us/step - loss: 0.1097 - val_loss: 0.7355
# Epoch 10/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 729us/step - loss: 0.0630 - val_loss: 0.0642
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 410us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 405us/step
# Fold accuracy: 0.9685432639649507
# Fold precision: 0.6484298331697743
# Fold recall: 0.9988662131519275
# Fold F1-score: 0.7863731032430824
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     43004
#            1       0.65      1.00      0.79      2646
#
#     accuracy                           0.97     45650
#    macro avg       0.82      0.98      0.88     45650
# weighted avg       0.98      0.97      0.97     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9695031320896147
# Mean precision: 0.6577589463130711
# Mean recall: 0.9981293775201656
# Mean F1-score: 0.7929205855542165
#
# El tiempo de ejecucion fue: 238.86328959465027
