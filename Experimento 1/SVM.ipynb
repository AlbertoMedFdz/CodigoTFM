# %% [markdown]
# _Alberto Medrano Fernández_
#
# # SVM

# %% [markdown]
# ---
#
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from time import time

from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler, LabelEncoder 
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.svm import LinearSVC
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.neural_network import BernoulliRBM
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

from tensorflow.keras.models import load_model, Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Input, Dense, BatchNormalization, ReLU, LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ---
#
# ## Dataset

# %%
hikari_2022 = pd.read_csv('ALLFLOWMETER_HIKARI2022.csv', sep=',')
hikari_2022
# Out:
#         Unnamed: 0                 uid       originh  originp  \
# 0                0  Cmu9v81jToQyRF1gbk  184.0.48.168    38164
# 1                1  CO21hl3TWkuXTOgajk  184.0.48.169    43068
# 2                2  CBLJ6L19FP0MfYX7Oh  184.0.48.124     5678
# 3                3  ChTG451zJ7hUYOcqje  184.0.48.124     5678
# 4                4  Cn9y6E2KVxzQbs5wjc  184.0.48.124     5678
# ...            ...                 ...           ...      ...
# 228248       16634   Clt16PPxzrXEtpa5d   184.0.48.20    53866
# 228249       53170  Cs8RA72uHDiQa5ch2k   184.0.48.20    54318
# 228250       53529  Cy4dqo4YEq5YGxjUXa   184.0.48.20    65355
# 228251       86308  CFXfNV3OTG04e0UnP4   184.0.48.20    53642
# 228252       99240  CqO7kc2eC5InNvWrtl   184.0.48.20    61000
#
#                 responh  responp           flow_duration  fwd_pkts_tot  \
# 0          184.0.48.150    50443  0 days 00:00:00.000060             1
# 1          184.0.48.150    50443  0 days 00:00:00.000083             1
# 2       255.255.255.255     5678  0 days 00:01:59.996602             3
# 3       255.255.255.255     5678  0 days 00:00:59.996909             2
# 4       255.255.255.255     5678  0 days 00:00:59.992130             2
# ...                 ...      ...                     ...           ...
# 228248     184.0.48.255     1947  0 days 00:00:00.000027             2
# 228249     184.0.48.255     1947  0 days 00:00:00.000027             2
# 228250     184.0.48.255     1947         0 days 00:00:00             2
# 228251     184.0.48.255     1947  0 days 00:00:00.000054             2
# 228252     184.0.48.255     1947         0 days 00:00:00             2
#
#         bwd_pkts_tot  fwd_data_pkts_tot  ...      idle.max      idle.tot  \
# 0                  1                  0  ...  0.000000e+00  0.000000e+00
# 1                  1                  0  ...  0.000000e+00  0.000000e+00
# 2                  0                  3  ...  5.999912e+07  1.199966e+08
# 3                  0                  2  ...  5.999691e+07  5.999691e+07
# 4                  0                  2  ...  5.999213e+07  5.999213e+07
# ...              ...                ...  ...           ...           ...
# 228248             0                  2  ...  0.000000e+00  0.000000e+00
# 228249             0                  2  ...  0.000000e+00  0.000000e+00
# 228250             0                  2  ...  0.000000e+00  0.000000e+00
# 228251             0                  2  ...  0.000000e+00  0.000000e+00
# 228252             0                  2  ...  0.000000e+00  0.000000e+00
#
#             idle.avg     idle.std  fwd_init_window_size  bwd_init_window_size  \
# 0       0.000000e+00     0.000000                 64240                     0
# 1       0.000000e+00     0.000000                 64240                     0
# 2       5.999830e+07  1156.846698                     0                     0
# 3       5.999691e+07     0.000000                     0                     0
# 4       5.999213e+07     0.000000                     0                     0
# ...              ...          ...                   ...                   ...
# 228248  0.000000e+00     0.000000                     0                     0
# 228249  0.000000e+00     0.000000                     0                     0
# 228250  0.000000e+00     0.000000                     0                     0
# 228251  0.000000e+00     0.000000                     0                     0
# 228252  0.000000e+00     0.000000                     0                     0
#
#         fwd_last_window_size  bwd_last_window_size      attack_category  Label
# 0                      64240                     0               Benign      0
# 1                      64240                     0               Benign      0
# 2                          0                     0               Benign      0
# 3                          0                     0               Benign      0
# 4                          0                     0               Benign      0
# ...                      ...                   ...                  ...    ...
# 228248                     0                     0  XMRIGCC CryptoMiner      1
# 228249                     0                     0  XMRIGCC CryptoMiner      1
# 228250                     0                     0  XMRIGCC CryptoMiner      1
# 228251                     0                     0  XMRIGCC CryptoMiner      1
# 228252                     0                     0  XMRIGCC CryptoMiner      1
#
# [228253 rows x 88 columns]

# %%
hikari_2022 = hikari_2022.drop(columns=['Unnamed: 0', 'uid', 'originh', 'responh', 'flow_duration', 'fwd_URG_flag_count', 
                                        'bwd_URG_flag_count', 'attack_category'])
hikari_2022
# Out:
#         originp  responp  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  \
# 0         38164    50443             1             1                  0
# 1         43068    50443             1             1                  0
# 2          5678     5678             3             0                  3
# 3          5678     5678             2             0                  2
# 4          5678     5678             2             0                  2
# ...         ...      ...           ...           ...                ...
# 228248    53866     1947             2             0                  2
# 228249    54318     1947             2             0                  2
# 228250    65355     1947             2             0                  2
# 228251    53642     1947             2             0                  2
# 228252    61000     1947             2             0                  2
#
#         bwd_data_pkts_tot  fwd_pkts_per_sec  bwd_pkts_per_sec  \
# 0                       0      16644.063492      16644.063492
# 1                       0      12052.597701      12052.597701
# 2                       0          0.025001          0.000000
# 3                       0          0.033335          0.000000
# 4                       0          0.033338          0.000000
# ...                   ...               ...               ...
# 228248                  0      73584.280702          0.000000
# 228249                  0      74235.469027          0.000000
# 228250                  0          0.000000          0.000000
# 228251                  0      37117.734513          0.000000
# 228252                  0          0.000000          0.000000
#
#         flow_pkts_per_sec  down_up_ratio  ...      idle.min      idle.max  \
# 0            33288.126984            1.0  ...  0.000000e+00  0.000000e+00
# 1            24105.195402            1.0  ...  0.000000e+00  0.000000e+00
# 2                0.025001            0.0  ...  5.999748e+07  5.999912e+07
# 3                0.033335            0.0  ...  5.999691e+07  5.999691e+07
# 4                0.033338            0.0  ...  5.999213e+07  5.999213e+07
# ...                   ...            ...  ...           ...           ...
# 228248       73584.280702            0.0  ...  0.000000e+00  0.000000e+00
# 228249       74235.469027            0.0  ...  0.000000e+00  0.000000e+00
# 228250           0.000000            0.0  ...  0.000000e+00  0.000000e+00
# 228251       37117.734513            0.0  ...  0.000000e+00  0.000000e+00
# 228252           0.000000            0.0  ...  0.000000e+00  0.000000e+00
#
#             idle.tot      idle.avg     idle.std  fwd_init_window_size  \
# 0       0.000000e+00  0.000000e+00     0.000000                 64240
# 1       0.000000e+00  0.000000e+00     0.000000                 64240
# 2       1.199966e+08  5.999830e+07  1156.846698                     0
# 3       5.999691e+07  5.999691e+07     0.000000                     0
# 4       5.999213e+07  5.999213e+07     0.000000                     0
# ...              ...           ...          ...                   ...
# 228248  0.000000e+00  0.000000e+00     0.000000                     0
# 228249  0.000000e+00  0.000000e+00     0.000000                     0
# 228250  0.000000e+00  0.000000e+00     0.000000                     0
# 228251  0.000000e+00  0.000000e+00     0.000000                     0
# 228252  0.000000e+00  0.000000e+00     0.000000                     0
#
#         bwd_init_window_size  fwd_last_window_size  bwd_last_window_size  \
# 0                          0                 64240                     0
# 1                          0                 64240                     0
# 2                          0                     0                     0
# 3                          0                     0                     0
# 4                          0                     0                     0
# ...                      ...                   ...                   ...
# 228248                     0                     0                     0
# 228249                     0                     0                     0
# 228250                     0                     0                     0
# 228251                     0                     0                     0
# 228252                     0                     0                     0
#
#         Label
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 228248      1
# 228249      1
# 228250      1
# 228251      1
# 228252      1
#
# [228253 rows x 80 columns]

# %%
# Calculate Pearson correlation coefficient
corr = hikari_2022.corr(method ='pearson')

# Extract the correlation with the target variable 'Label'
corr_with_target = corr['Label']

# Select only columns with a correlation less than 0.05
relevant_features = corr_with_target[abs(corr_with_target) >= 0.05].index

# Filter the DataFrame to keep only the relevant features
hikari_2022 = hikari_2022[relevant_features]

print("Dataset after EDA:")
hikari_2022
# Out:
# Dataset after EDA:
#         originp  responp  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  \
# 0         38164    50443             1             1                  0
# 1         43068    50443             1             1                  0
# 2          5678     5678             3             0                  3
# 3          5678     5678             2             0                  2
# 4          5678     5678             2             0                  2
# ...         ...      ...           ...           ...                ...
# 228248    53866     1947             2             0                  2
# 228249    54318     1947             2             0                  2
# 228250    65355     1947             2             0                  2
# 228251    53642     1947             2             0                  2
# 228252    61000     1947             2             0                  2
#
#         bwd_data_pkts_tot  bwd_pkts_per_sec  down_up_ratio  \
# 0                       0      16644.063492            1.0
# 1                       0      12052.597701            1.0
# 2                       0          0.000000            0.0
# 3                       0          0.000000            0.0
# 4                       0          0.000000            0.0
# ...                   ...               ...            ...
# 228248                  0          0.000000            0.0
# 228249                  0          0.000000            0.0
# 228250                  0          0.000000            0.0
# 228251                  0          0.000000            0.0
# 228252                  0          0.000000            0.0
#
#         fwd_header_size_tot  fwd_header_size_min  ...  bwd_subflow_bytes  \
# 0                        40                   40  ...                0.0
# 1                        40                   40  ...                0.0
# 2                        24                    8  ...                0.0
# 3                        16                    8  ...                0.0
# 4                        16                    8  ...                0.0
# ...                     ...                  ...  ...                ...
# 228248                   16                    8  ...                0.0
# 228249                   16                    8  ...                0.0
# 228250                   16                    8  ...                0.0
# 228251                   16                    8  ...                0.0
# 228252                   16                    8  ...                0.0
#
#         fwd_bulk_packets  bwd_bulk_packets  active.min  active.max  \
# 0                    0.0               0.0   60.081482   60.081482
# 1                    0.0               0.0   82.969666   82.969666
# 2                    0.0               0.0    0.000000    0.000000
# 3                    0.0               0.0    0.000000    0.000000
# 4                    0.0               0.0    0.000000    0.000000
# ...                  ...               ...         ...         ...
# 228248               0.0               0.0   27.179718   27.179718
# 228249               0.0               0.0   26.941299   26.941299
# 228250               0.0               0.0    0.000000    0.000000
# 228251               0.0               0.0   53.882599   53.882599
# 228252               0.0               0.0    0.000000    0.000000
#
#         active.avg  fwd_init_window_size  bwd_init_window_size  \
# 0        60.081482                 64240                     0
# 1        82.969666                 64240                     0
# 2         0.000000                     0                     0
# 3         0.000000                     0                     0
# 4         0.000000                     0                     0
# ...            ...                   ...                   ...
# 228248   27.179718                     0                     0
# 228249   26.941299                     0                     0
# 228250    0.000000                     0                     0
# 228251   53.882599                     0                     0
# 228252    0.000000                     0                     0
#
#         fwd_last_window_size  Label
# 0                      64240      0
# 1                      64240      0
# 2                          0      0
# 3                          0      0
# 4                          0      0
# ...                      ...    ...
# 228248                     0      1
# 228249                     0      1
# 228250                     0      1
# 228251                     0      1
# 228252                     0      1
#
# [228253 rows x 44 columns]

# %% [markdown]
# ---
#
# ## Models

# %% [markdown]
# ### Without feature extraction

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Cross-validation
def cross_validation(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []

    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        # Train SVM classifier
        svm_classifier = LinearSVC(class_weight='balanced', max_iter=10000)
        svm_classifier.fit(X_train, y_train)

        # Make predictions
        y_pred = svm_classifier.predict(X_test)

        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")   



tiempo_inicial = time()
#
cross_validation(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# Fold accuracy: 0.9720926157148803
# Fold precision: 0.6777299214593362
# Fold recall: 0.999252895031752
# Fold F1-score: 0.8076690821256038
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     42974
#            1       0.68      1.00      0.81      2677
#
#     accuracy                           0.97     45651
#    macro avg       0.84      0.98      0.90     45651
# weighted avg       0.98      0.97      0.97     45651
#
# Fold accuracy: 0.9719392784385884
# Fold precision: 0.6807017543859649
# Fold recall: 0.9974293059125964
# Fold F1-score: 0.8091762252346194
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     42928
#            1       0.68      1.00      0.81      2723
#
#     accuracy                           0.97     45651
#    macro avg       0.84      0.98      0.90     45651
# weighted avg       0.98      0.97      0.97     45651
#
# Fold accuracy: 0.9728812074215242
# Fold precision: 0.6778821074595722
# Fold recall: 0.9988470407378939
# Fold F1-score: 0.807644499689248
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     43049
#            1       0.68      1.00      0.81      2602
#
#     accuracy                           0.97     45651
#    macro avg       0.84      0.99      0.90     45651
# weighted avg       0.98      0.97      0.98     45651
#
# Fold accuracy: 0.9705147864184008
# Fold precision: 0.6674907292954264
# Fold recall: 0.9996297667530544
# Fold F1-score: 0.8004743551734361
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     42949
#            1       0.67      1.00      0.80      2701
#
#     accuracy                           0.97     45650
#    macro avg       0.83      0.98      0.89     45650
# weighted avg       0.98      0.97      0.97     45650
#
# Fold accuracy: 0.9708433734939759
# Fold precision: 0.6654088050314465
# Fold recall: 0.9996220710506425
# Fold F1-score: 0.7989729648089412
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     43004
#            1       0.67      1.00      0.80      2646
#
#     accuracy                           0.97     45650
#    macro avg       0.83      0.98      0.89     45650
# weighted avg       0.98      0.97      0.97     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9716542522974739
# Mean precision: 0.6738426635263493
# Mean recall: 0.9989562158971879
# Mean F1-score: 0.8047874254063696
#
# El tiempo de ejecucion fue: 179.26589512825012

# %% [markdown]
# ---
#
# ### With DNN

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the DNN model
def create_dnn(input_dim):
    inputs = Input(shape=(input_dim,))
    
    # Hidden layer 1
    x = Dense(input_dim * 2)(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    # Hidden layer 2
    x = Dense(input_dim)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    # Feature layer
    n_bottleneck = round(float(input_dim) / 2.0)
    bottleneck = Dense(n_bottleneck)(x)
    bottleneck = BatchNormalization()(bottleneck)
    bottleneck = ReLU()(bottleneck)
    
    # Output layer
    outputs = Dense(1, activation='sigmoid')(bottleneck)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    # Model for feature extraction
    feature_extractor = Model(inputs=inputs, outputs=bottleneck)
    
    return model, feature_extractor

# Cross-validation
def cross_validation_dnn(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        dnn, feature_extractor = create_dnn(n_inputs)
        
        # Early Stopping
        early_stopping1 = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)
        early_stopping2 = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
        
        # Fit the DNN model
        dnn.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1,
                        validation_data=(X_test, y_test),
                        callbacks=[early_stopping1, early_stopping2])
        
        # Encode the data
        X_train_encoded = feature_extractor.predict(X_train)
        X_test_encoded = feature_extractor.predict(X_test)
        
        # Train SVM classifier
        svm_classifier_encoded = LinearSVC(class_weight='balanced', max_iter=10000)
        svm_classifier_encoded.fit(X_train_encoded, y_train)
        
        # Make predictions
        y_pred_encoded = svm_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")


tiempo_inicial = time()
#
cross_validation_dnn(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 853us/step - accuracy: 0.9691 - loss: 0.0907 - val_accuracy: 0.9812 - val_loss: 0.0306
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 823us/step - accuracy: 0.9838 - loss: 0.0266 - val_accuracy: 0.9828 - val_loss: 0.0310
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 837us/step - accuracy: 0.9848 - loss: 0.0243 - val_accuracy: 0.9835 - val_loss: 0.0262
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 838us/step - accuracy: 0.9846 - loss: 0.0243 - val_accuracy: 0.9823 - val_loss: 0.0248
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 827us/step - accuracy: 0.9847 - loss: 0.0239 - val_accuracy: 0.9828 - val_loss: 0.0287
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 829us/step - accuracy: 0.9844 - loss: 0.0236 - val_accuracy: 0.9843 - val_loss: 0.0239
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 836us/step - accuracy: 0.9841 - loss: 0.0241 - val_accuracy: 0.9844 - val_loss: 0.0240
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 826us/step - accuracy: 0.9848 - loss: 0.0239 - val_accuracy: 0.9844 - val_loss: 0.0240
# Epoch 9/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 845us/step - accuracy: 0.9844 - loss: 0.0239 - val_accuracy: 0.9842 - val_loss: 0.0234
# Epoch 10/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 825us/step - accuracy: 0.9846 - loss: 0.0231 - val_accuracy: 0.9844 - val_loss: 0.0238
# Epoch 11/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 838us/step - accuracy: 0.9847 - loss: 0.0230 - val_accuracy: 0.9838 - val_loss: 0.0242
# Epoch 12/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 827us/step - accuracy: 0.9844 - loss: 0.0235 - val_accuracy: 0.9844 - val_loss: 0.0236
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 450us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 442us/step
# Fold accuracy: 0.9823004972508816
# Fold precision: 0.768303186907838
# Fold recall: 0.9996264475158759
# Fold F1-score: 0.8688311688311688
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     42974
#            1       0.77      1.00      0.87      2677
#
#     accuracy                           0.98     45651
#    macro avg       0.88      0.99      0.93     45651
# weighted avg       0.99      0.98      0.98     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 843us/step - accuracy: 0.9757 - loss: 0.0752 - val_accuracy: 0.9819 - val_loss: 0.0311
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 844us/step - accuracy: 0.9839 - loss: 0.0259 - val_accuracy: 0.9834 - val_loss: 0.0272
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 843us/step - accuracy: 0.9838 - loss: 0.0249 - val_accuracy: 0.9837 - val_loss: 0.0252
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 873us/step - accuracy: 0.9848 - loss: 0.0237 - val_accuracy: 0.9836 - val_loss: 0.0254
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 909us/step - accuracy: 0.9846 - loss: 0.0246 - val_accuracy: 0.9836 - val_loss: 0.0255
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 872us/step - accuracy: 0.9843 - loss: 0.0236 - val_accuracy: 0.9835 - val_loss: 0.0267
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 483us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 446us/step
# Fold accuracy: 0.9820814439990362
# Fold precision: 0.7702127659574468
# Fold recall: 0.9970620639001102
# Fold F1-score: 0.8690781049935979
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     42928
#            1       0.77      1.00      0.87      2723
#
#     accuracy                           0.98     45651
#    macro avg       0.89      0.99      0.93     45651
# weighted avg       0.99      0.98      0.98     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 7s 877us/step - accuracy: 0.9742 - loss: 0.0774 - val_accuracy: 0.9828 - val_loss: 0.0256
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 866us/step - accuracy: 0.9836 - loss: 0.0269 - val_accuracy: 0.9852 - val_loss: 0.0245
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 897us/step - accuracy: 0.9837 - loss: 0.0255 - val_accuracy: 0.9850 - val_loss: 0.0239
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 868us/step - accuracy: 0.9838 - loss: 0.0247 - val_accuracy: 0.9854 - val_loss: 0.0232
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 824us/step - accuracy: 0.9842 - loss: 0.0248 - val_accuracy: 0.9853 - val_loss: 0.0232
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 827us/step - accuracy: 0.9846 - loss: 0.0246 - val_accuracy: 0.9854 - val_loss: 0.0224
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 822us/step - accuracy: 0.9844 - loss: 0.0243 - val_accuracy: 0.9853 - val_loss: 0.0228
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 821us/step - accuracy: 0.9837 - loss: 0.0244 - val_accuracy: 0.9854 - val_loss: 0.0228
# Epoch 9/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 826us/step - accuracy: 0.9845 - loss: 0.0242 - val_accuracy: 0.9854 - val_loss: 0.0223
# Epoch 10/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 818us/step - accuracy: 0.9841 - loss: 0.0240 - val_accuracy: 0.9853 - val_loss: 0.0231
# Epoch 11/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 818us/step - accuracy: 0.9841 - loss: 0.0243 - val_accuracy: 0.9854 - val_loss: 0.0226
# Epoch 12/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 818us/step - accuracy: 0.9844 - loss: 0.0241 - val_accuracy: 0.9841 - val_loss: 0.0225
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 452us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 449us/step
# Fold accuracy: 0.9828481303804955
# Fold precision: 0.7691624741047647
# Fold recall: 0.9988470407378939
# Fold F1-score: 0.8690854372178566
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     43049
#            1       0.77      1.00      0.87      2602
#
#     accuracy                           0.98     45651
#    macro avg       0.88      0.99      0.93     45651
# weighted avg       0.99      0.98      0.98     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 853us/step - accuracy: 0.9647 - loss: 0.0963 - val_accuracy: 0.9836 - val_loss: 0.0255
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 826us/step - accuracy: 0.9836 - loss: 0.0265 - val_accuracy: 0.9846 - val_loss: 0.0242
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 830us/step - accuracy: 0.9844 - loss: 0.0247 - val_accuracy: 0.9846 - val_loss: 0.0249
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 830us/step - accuracy: 0.9843 - loss: 0.0242 - val_accuracy: 0.9846 - val_loss: 0.0236
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 825us/step - accuracy: 0.9846 - loss: 0.0237 - val_accuracy: 0.9821 - val_loss: 0.0273
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 834us/step - accuracy: 0.9847 - loss: 0.0239 - val_accuracy: 0.9846 - val_loss: 0.0237
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 825us/step - accuracy: 0.9844 - loss: 0.0239 - val_accuracy: 0.9844 - val_loss: 0.0244
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 451us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 440us/step
# Fold accuracy: 0.9817305585980285
# Fold precision: 0.764073550212164
# Fold recall: 1.0
# Fold F1-score: 0.8662604233483002
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     42949
#            1       0.76      1.00      0.87      2701
#
#     accuracy                           0.98     45650
#    macro avg       0.88      0.99      0.93     45650
# weighted avg       0.99      0.98      0.98     45650
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 853us/step - accuracy: 0.9729 - loss: 0.0812 - val_accuracy: 0.9848 - val_loss: 0.0249
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 833us/step - accuracy: 0.9833 - loss: 0.0263 - val_accuracy: 0.9851 - val_loss: 0.0241
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 828us/step - accuracy: 0.9837 - loss: 0.0252 - val_accuracy: 0.9846 - val_loss: 0.0263
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 833us/step - accuracy: 0.9840 - loss: 0.0252 - val_accuracy: 0.9841 - val_loss: 0.0269
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 823us/step - accuracy: 0.9841 - loss: 0.0247 - val_accuracy: 0.9851 - val_loss: 0.0236
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 824us/step - accuracy: 0.9849 - loss: 0.0235 - val_accuracy: 0.9850 - val_loss: 0.0227
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 821us/step - accuracy: 0.9847 - loss: 0.0237 - val_accuracy: 0.9851 - val_loss: 0.0232
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 832us/step - accuracy: 0.9845 - loss: 0.0240 - val_accuracy: 0.9853 - val_loss: 0.0223
# Epoch 9/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 825us/step - accuracy: 0.9842 - loss: 0.0241 - val_accuracy: 0.9852 - val_loss: 0.0223
# Epoch 10/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 827us/step - accuracy: 0.9845 - loss: 0.0239 - val_accuracy: 0.9852 - val_loss: 0.0218
# Epoch 11/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 824us/step - accuracy: 0.9848 - loss: 0.0232 - val_accuracy: 0.9853 - val_loss: 0.0224
# Epoch 12/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 827us/step - accuracy: 0.9841 - loss: 0.0237 - val_accuracy: 0.9852 - val_loss: 0.0222
# Epoch 13/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 816us/step - accuracy: 0.9845 - loss: 0.0232 - val_accuracy: 0.9853 - val_loss: 0.0220
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 3s 449us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 442us/step
# Fold accuracy: 0.983329682365827
# Fold precision: 0.7766363369533313
# Fold recall: 1.0
# Fold F1-score: 0.8742772179084751
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     43004
#            1       0.78      1.00      0.87      2646
#
#     accuracy                           0.98     45650
#    macro avg       0.89      0.99      0.93     45650
# weighted avg       0.99      0.98      0.98     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9824580625188538
# Mean precision: 0.769677662827109
# Mean recall: 0.999107110430776
# Mean F1-score: 0.8695064704598797
#
# El tiempo de ejecucion fue: 274.7109887599945

# %% [markdown]
# ---
#
# ### With DBN

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the DBN class
class DBN(BaseEstimator, TransformerMixin):
    def __init__(self, rbm_layers, rbm_learning_rate, rbm_n_iter):
        self.rbm_layers = rbm_layers
        self.rbm_learning_rate = rbm_learning_rate
        self.rbm_n_iter = rbm_n_iter
        self.rbms = []
        for i, n_components in enumerate(rbm_layers):
            self.rbms.append(BernoulliRBM(n_components=n_components, learning_rate=rbm_learning_rate, n_iter=rbm_n_iter, verbose=1))

    def fit(self, X, y=None):
        input_data = X
        for rbm in self.rbms:
            rbm.fit(input_data)
            input_data = rbm.transform(input_data)
        return self

    def transform(self, X):
        input_data = X
        for rbm in self.rbms:
            input_data = rbm.transform(input_data)
        return input_data

# Cross-validation
def cross_validation_dbn(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Normalize data
        scaler = MinMaxScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        dbn = DBN(rbm_layers=[n_inputs*2, n_inputs], rbm_learning_rate=0.1, rbm_n_iter=10)
        
        # Fit the DBN model
        dbn.fit(X_train)
        
        # Encode the data
        X_train_encoded = dbn.transform(X_train)
        X_test_encoded = dbn.transform(X_test)
        
        # Train SVM classifier
        svm_classifier_encoded = LinearSVC(class_weight='balanced', max_iter=10000)
        svm_classifier_encoded.fit(X_train_encoded, y_train)
        
        # Make predictions
        y_pred_encoded = svm_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")
    
    
tiempo_inicial = time()
#
cross_validation_dbn(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -6.14, time = 2.41s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.61, time = 3.13s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.10, time = 3.14s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.88, time = 3.19s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.58, time = 3.17s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -5.22, time = 3.34s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.68, time = 3.16s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.66, time = 3.16s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.51, time = 3.11s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.75, time = 3.12s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.80, time = 2.36s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.37, time = 2.83s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.48, time = 2.77s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.61, time = 2.77s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.55, time = 2.83s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.45, time = 2.85s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.45, time = 2.88s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.41, time = 2.81s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.58, time = 2.78s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.36, time = 2.79s
# Fold accuracy: 0.9070776105671289
# Fold precision: 0.3334043006174154
# Fold recall: 0.5849831901382144
# Fold F1-score: 0.4247355573637103
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     42974
#            1       0.33      0.58      0.42      2677
#
#     accuracy                           0.91     45651
#    macro avg       0.65      0.76      0.69     45651
# weighted avg       0.94      0.91      0.92     45651
#
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -6.33, time = 2.53s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.53, time = 3.25s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.23, time = 3.21s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.09, time = 3.16s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -5.00, time = 3.18s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.91, time = 3.35s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.77, time = 3.23s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.76, time = 3.13s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.75, time = 3.22s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.83, time = 3.12s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.69, time = 2.45s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.19, time = 2.86s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.26, time = 2.80s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.15, time = 2.84s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.26, time = 2.81s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.49, time = 2.83s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.14, time = 3.00s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.25, time = 2.87s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.32, time = 2.83s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.30, time = 2.85s
# Fold accuracy: 0.9027184508554029
# Fold precision: 0.32419156774457636
# Fold recall: 0.5817113477781858
# Fold F1-score: 0.4163490603233014
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.95     42928
#            1       0.32      0.58      0.42      2723
#
#     accuracy                           0.90     45651
#    macro avg       0.65      0.75      0.68     45651
# weighted avg       0.93      0.90      0.92     45651
#
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -6.17, time = 2.45s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.89, time = 3.30s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.31, time = 3.19s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -5.00, time = 3.23s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.89, time = 3.27s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.79, time = 3.22s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.99, time = 3.39s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.74, time = 3.17s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.74, time = 3.18s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.74, time = 3.09s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.24, time = 2.37s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -3.59, time = 2.90s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -3.50, time = 2.81s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -3.88, time = 2.84s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -3.70, time = 2.81s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -3.87, time = 2.89s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -3.52, time = 2.94s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -3.57, time = 3.11s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -3.59, time = 2.95s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -3.57, time = 2.78s
# Fold accuracy: 0.9070337999167598
# Fold precision: 0.31820194862710366
# Fold recall: 0.5522674865488086
# Fold F1-score: 0.403765102556898
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     43049
#            1       0.32      0.55      0.40      2602
#
#     accuracy                           0.91     45651
#    macro avg       0.64      0.74      0.68     45651
# weighted avg       0.93      0.91      0.92     45651
#
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.47, time = 2.45s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -5.17, time = 3.18s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -5.09, time = 3.41s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.79, time = 3.23s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.51, time = 3.27s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.64, time = 3.16s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.64, time = 3.35s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.63, time = 3.30s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.73, time = 3.22s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.57, time = 3.15s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.38, time = 2.40s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.29, time = 2.81s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.18, time = 2.90s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.41, time = 2.84s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.35, time = 2.82s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.37, time = 2.77s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.37, time = 2.79s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.34, time = 2.90s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.34, time = 2.83s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.42, time = 2.85s
# Fold accuracy: 0.7219715224534502
# Fold precision: 0.11635051071346286
# Fold recall: 0.5609033691225472
# Fold F1-score: 0.19272357206462282
#               precision    recall  f1-score   support
#
#            0       0.96      0.73      0.83     42949
#            1       0.12      0.56      0.19      2701
#
#     accuracy                           0.72     45650
#    macro avg       0.54      0.65      0.51     45650
# weighted avg       0.91      0.72      0.79     45650
#
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -5.04, time = 2.48s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.78, time = 3.16s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.99, time = 3.32s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.73, time = 3.22s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.71, time = 3.24s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.53, time = 3.28s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.77, time = 3.26s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.81, time = 3.29s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.42, time = 3.14s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.57, time = 3.12s
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -4.75, time = 2.40s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -4.63, time = 2.86s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -4.40, time = 2.86s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -4.49, time = 2.86s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -4.71, time = 2.78s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -4.66, time = 2.81s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -4.64, time = 2.90s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -4.66, time = 2.78s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -4.52, time = 2.89s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -4.82, time = 2.85s
# Fold accuracy: 0.908368017524644
# Fold precision: 0.3301657458563536
# Fold recall: 0.564625850340136
# Fold F1-score: 0.41667828754706454
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     43004
#            1       0.33      0.56      0.42      2646
#
#     accuracy                           0.91     45650
#    macro avg       0.65      0.75      0.68     45650
# weighted avg       0.93      0.91      0.92     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.8694338802634771
# Mean precision: 0.28446281471178236
# Mean recall: 0.5688982487855785
# Mean F1-score: 0.3708503159711194
#
# El tiempo de ejecucion fue: 308.68807578086853

# %% [markdown]
# ---
#
# ### With Autoencoder

# %%
X = hikari_2022.iloc[:, :-1]
y = hikari_2022['Label']

# Define the autoencoder model
def create_autoencoder(n_inputs):
    inputs = Input(shape=(n_inputs,))
    
    # Define Encoder
    e = Dense(n_inputs*2)(inputs)
    e = BatchNormalization()(e)
    e = LeakyReLU()(e)
    
    # Bottleneck
    n_bottleneck = round(float(n_inputs)/2.0)
    bottleneck = Dense(n_bottleneck)(e)
    
    # Define Decoder
    d = Dense(n_inputs*2)(bottleneck)
    d = BatchNormalization()(d)
    d = LeakyReLU()(d)
    
    # Output layer
    outputs = Dense(n_inputs, activation='linear')(d)
    
    # Define autoencoder model
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='mse')
    
    # Define encoder model
    encoder = Model(inputs=inputs, outputs=bottleneck)
    
    return model, encoder

# Cross-validation
def cross_validation_autoencoder(X, y, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Normalize data
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        n_inputs = X_train.shape[1]
        autoencoder, encoder = create_autoencoder(n_inputs)
        
        # Early Stopping
        early_stopping1 = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)
        early_stopping2 = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
        
        # Fit the autoencoder model
        autoencoder.fit(X_train, X_train, epochs=100, batch_size=32, verbose=1,
                        validation_data=(X_test, X_test),
                        callbacks=[early_stopping1, early_stopping2])
        
        # Encode the data
        X_train_encoded = encoder.predict(X_train)
        X_test_encoded = encoder.predict(X_test)
        
        # Train SVM classifier
        svm_classifier_encoded = LinearSVC(class_weight='balanced', max_iter=10000)
        svm_classifier_encoded.fit(X_train_encoded, y_train)
        
        # Make predictions
        y_pred_encoded = svm_classifier_encoded.predict(X_test_encoded)
        
        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred_encoded)
        accuracies.append(accuracy)
        
        precision = precision_score(y_test, y_pred_encoded)
        precisions.append(precision)
        
        recall = recall_score(y_test, y_pred_encoded)
        recalls.append(recall)
        
        f1 = f1_score(y_test, y_pred_encoded)
        f1_scores.append(f1)
        
        print(f"Fold accuracy: {accuracy}")
        print(f"Fold precision: {precision}")
        print(f"Fold recall: {recall}")
        print(f"Fold F1-score: {f1}")
        
        # Generate classification report
        report = classification_report(y_test, y_pred_encoded)
        print(report)
    
    mean_accuracy = np.mean(accuracies)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)
    
    print("Mean classification report:")
    print("==========================")
    print(f"Mean accuracy: {mean_accuracy}")
    print(f"Mean precision: {mean_precision}")
    print(f"Mean recall: {mean_recall}")
    print(f"Mean F1-score: {mean_f1}")


tiempo_inicial = time()
#
cross_validation_autoencoder(X, y)
#
tiempo_final = time() 
tiempo_ejecucion = tiempo_final - tiempo_inicial
print ('\nEl tiempo de ejecucion fue:', tiempo_ejecucion) # Seconds
# Out:
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 748us/step - loss: 0.3397 - val_loss: 0.0743
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 726us/step - loss: 0.1348 - val_loss: 0.0454
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 735us/step - loss: 0.1105 - val_loss: 0.0581
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 734us/step - loss: 0.1045 - val_loss: 0.0616
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 734us/step - loss: 0.1037 - val_loss: 0.0442
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 729us/step - loss: 0.1082 - val_loss: 0.0623
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 731us/step - loss: 0.1152 - val_loss: 0.0490
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 728us/step - loss: 0.0927 - val_loss: 0.0392
# Epoch 9/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 725us/step - loss: 0.0678 - val_loss: 0.0565
# Epoch 10/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 735us/step - loss: 0.0665 - val_loss: 0.0396
# Epoch 11/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 729us/step - loss: 0.0662 - val_loss: 0.0340
# Epoch 12/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 731us/step - loss: 0.0528 - val_loss: 0.0849
# Epoch 13/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 725us/step - loss: 0.0705 - val_loss: 0.0263
# Epoch 14/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 733us/step - loss: 0.0915 - val_loss: 0.0595
# Epoch 15/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 726us/step - loss: 0.0675 - val_loss: 0.0632
# Epoch 16/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 726us/step - loss: 0.0531 - val_loss: 0.0295
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 413us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 407us/step
# Fold accuracy: 0.9685877636853519
# Fold precision: 0.651400730816078
# Fold recall: 0.9988793425476279
# Fold F1-score: 0.7885579475081097
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     42974
#            1       0.65      1.00      0.79      2677
#
#     accuracy                           0.97     45651
#    macro avg       0.83      0.98      0.89     45651
# weighted avg       0.98      0.97      0.97     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 747us/step - loss: 0.2505 - val_loss: 0.2273
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 727us/step - loss: 0.1798 - val_loss: 0.0823
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 728us/step - loss: 0.1628 - val_loss: 0.1445
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 729us/step - loss: 0.1722 - val_loss: 0.0889
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 728us/step - loss: 0.1521 - val_loss: 0.1294
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 414us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 410us/step
# Fold accuracy: 0.9430461545201638
# Fold precision: 0.5116631898350086
# Fold recall: 0.9908189496878443
# Fold F1-score: 0.6748374187093547
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97     42928
#            1       0.51      0.99      0.67      2723
#
#     accuracy                           0.94     45651
#    macro avg       0.76      0.97      0.82     45651
# weighted avg       0.97      0.94      0.95     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 6s 747us/step - loss: 0.2290 - val_loss: 1.0010
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 730us/step - loss: 0.1805 - val_loss: 1.6225
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 727us/step - loss: 0.1440 - val_loss: 2.5974
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 727us/step - loss: 0.1325 - val_loss: 2.1529
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 414us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 416us/step
# Fold accuracy: 0.9628266631618146
# Fold precision: 0.6059967205434528
# Fold recall: 0.9942352036894696
# Fold F1-score: 0.7530199388735264
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     43049
#            1       0.61      0.99      0.75      2602
#
#     accuracy                           0.96     45651
#    macro avg       0.80      0.98      0.87     45651
# weighted avg       0.98      0.96      0.97     45651
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 748us/step - loss: 0.3171 - val_loss: 0.2169
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 732us/step - loss: 0.1536 - val_loss: 0.3800
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 735us/step - loss: 0.1214 - val_loss: 0.0825
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 737us/step - loss: 0.1029 - val_loss: 0.0671
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 738us/step - loss: 0.0905 - val_loss: 0.0500
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 725us/step - loss: 0.1251 - val_loss: 0.0987
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 730us/step - loss: 0.1136 - val_loss: 0.2415
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 720us/step - loss: 0.0869 - val_loss: 0.0511
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 406us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 401us/step
# Fold accuracy: 0.9651478641840088
# Fold precision: 0.6294913672421839
# Fold recall: 0.9988893002591632
# Fold F1-score: 0.7722913983111492
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     42949
#            1       0.63      1.00      0.77      2701
#
#     accuracy                           0.97     45650
#    macro avg       0.81      0.98      0.88     45650
# weighted avg       0.98      0.97      0.97     45650
#
# Epoch 1/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 5s 736us/step - loss: 0.3013 - val_loss: 1.1342
# Epoch 2/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 718us/step - loss: 0.1841 - val_loss: 0.2589
# Epoch 3/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 714us/step - loss: 0.1869 - val_loss: 0.4056
# Epoch 4/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 718us/step - loss: 0.1625 - val_loss: 0.0948
# Epoch 5/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 729us/step - loss: 0.1075 - val_loss: 0.0573
# Epoch 6/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 727us/step - loss: 0.0826 - val_loss: 0.1218
# Epoch 7/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 715us/step - loss: 0.1157 - val_loss: 0.6198
# Epoch 8/100
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 4s 712us/step - loss: 0.1176 - val_loss: 0.0923
# 5707/5707 ━━━━━━━━━━━━━━━━━━━━ 2s 406us/step
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 1s 414us/step
# Fold accuracy: 0.9672727272727273
# Fold precision: 0.6394673123486683
# Fold recall: 0.9981103552532123
# Fold F1-score: 0.7795159386068476
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     43004
#            1       0.64      1.00      0.78      2646
#
#     accuracy                           0.97     45650
#    macro avg       0.82      0.98      0.88     45650
# weighted avg       0.98      0.97      0.97     45650
#
# Mean classification report:
# ==========================
# Mean accuracy: 0.9613762345648134
# Mean precision: 0.6076038641570782
# Mean recall: 0.9961866302874635
# Mean F1-score: 0.7536445284017975
#
# El tiempo de ejecucion fue: 205.07361960411072
